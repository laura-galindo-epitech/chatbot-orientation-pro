# %% [markdown]
# # Building a Retrieval Augmented Generation (RAG) Chatbot

# %%
# !pip install --quiet --upgrade langchain-text-splitters langchain-community langgraph
# !pip install -qU langchain-mistralai
# !pip install -qU langchain-chroma
# !pip install -qU chromadb
# !pip install xmltodict

# To correct UnstructuredXMLLoader errors
# !pip install "unstructured>=0.6.7"

# %% [markdown]
# ## Setup

# %%
import getpass
import os

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter API key for Langsmith: ")
# Out:
# Enter API key for Langsmith:  ········

# %% [markdown]
# ## Components

# %%
import getpass
import os

# Chat model

MODEL_NAME = "mistral-small-latest"
MISTRAL_API_KEY = getpass.getpass("Enter API key for Mistral AI: ")
# Out:
# Enter API key for Mistral AI:  ········

# %%
from langchain_mistralai import ChatMistralAI, MistralAIEmbeddings

# Chat model initialization
llm = ChatMistralAI(
    mistral_api_key=MISTRAL_API_KEY,
    model="mistral-small-latest",
    streaming=True,
    temperature=0.6
)

# Embeddings model
embeddings = MistralAIEmbeddings(model="mistral-embed")

# %%
from langchain_chroma import Chroma

# Vector store
vector_store = Chroma(embedding_function=embeddings)

# %% [markdown]
# ## Loading JSON and XML files
#
# Transforming the data JSON and XML files we got online into LangChain Document objects

# %% [markdown]
# ### Test: loading a single JSON file

# %%
import json
from pathlib import Path
from pprint import pprint

file_path="../parcoursup/parcoursup_data.json"
data = json.loads(Path(file_path).read_text())
pprint(data)
# Out:
# [{'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Pluri Langues',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Pluri Sciences fondamentales et applications',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Sciences de la vie, biologie, santÃ©',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': "Ecoles d'ingÃ©nieurs",
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'DCG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 34.0,
#   'voeux': 76},
#  {'acceptations': 50,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 214.0,
#   'voeux': 348},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 12,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 68.0,
#   'voeux': 128},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Pluri Sciences',
#   'propositions_d_admissions': 5.0,
#   'voeux': 10},
#  {'acceptations': 56,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Sciences de l information et de la communication',
#   'propositions_d_admissions': 151.0,
#   'voeux': 296},
#  {'acceptations': 42,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 82.0,
#   'voeux': 155},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Sciences Ã©conomiques',
#   'propositions_d_admissions': 2.0,
#   'voeux': 10},
#  {'acceptations': 76,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 151.0,
#   'voeux': 228},
#  {'acceptations': 8,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 8.0,
#   'voeux': 49},
#  {'acceptations': 17,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'D.E sanitaire',
#   'propositions_d_admissions': 20.0,
#   'voeux': 68},
#  {'acceptations': 14,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'DEUST',
#   'propositions_d_admissions': 25.0,
#   'voeux': 61},
#  {'acceptations': 10,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 10.0,
#   'voeux': 207},
#  {'acceptations': 2249,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 2693.0,
#   'voeux': 3022},
#  {'acceptations': 171,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 550.0,
#   'voeux': 679},
#  {'acceptations': 32,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 138.0,
#   'voeux': 220},
#  {'acceptations': 234,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 838.0,
#   'voeux': 1097},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 89,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 398.0,
#   'voeux': 544},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Pluri Sciences',
#   'propositions_d_admissions': 5.0,
#   'voeux': 14},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 2.0,
#   'voeux': 9},
#  {'acceptations': 40,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 238.0,
#   'voeux': 342},
#  {'acceptations': 8,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 49.0,
#   'voeux': 1412},
#  {'acceptations': 47,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 76.0,
#   'voeux': 348},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 3.0,
#   'voeux': 10},
#  {'acceptations': 141,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 270.0,
#   'voeux': 424},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 5.0,
#   'voeux': 23},
#  {'acceptations': 19,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 105.0,
#   'voeux': 183},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Pluri Langues',
#   'propositions_d_admissions': 10.0,
#   'voeux': 46},
#  {'acceptations': 180,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 388.0,
#   'voeux': 845},
#  {'acceptations': 41,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 105.0,
#   'voeux': 213},
#  {'acceptations': 37,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 160.0,
#   'voeux': 247},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 8.0,
#   'voeux': 51},
#  {'acceptations': 15,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 50.0,
#   'voeux': 1917},
#  {'acceptations': 24,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'BUT Production',
#   'propositions_d_admissions': 54.0,
#   'voeux': 241},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'CPGE S',
#   'propositions_d_admissions': 19.0,
#   'voeux': 150},
#  {'acceptations': 23,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 36.0,
#   'voeux': 97},
#  {'acceptations': 15,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 18.0,
#   'voeux': 58},
#  {'acceptations': 342,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 577.0,
#   'voeux': 2108},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'DCG',
#   'propositions_d_admissions': 2.0,
#   'voeux': 8},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 8.0,
#   'voeux': 14},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence GÃ©nie civil',
#   'propositions_d_admissions': 9.0,
#   'voeux': 18},
#  {'acceptations': 16,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 46.0,
#   'voeux': 62},
#  {'acceptations': 12,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 45.0,
#   'voeux': 77},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence MÃ©canique, GÃ©nie mÃ©canique, IngÃ©nierie mÃ©canique',
#   'propositions_d_admissions': 1.0,
#   'voeux': 4},
#  {'acceptations': 29,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 88.0,
#   'voeux': 157},
#  {'acceptations': 19,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 39.0,
#   'voeux': 61},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 17.0,
#   'voeux': 29},
#  {'acceptations': 18,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 43.0,
#   'voeux': 160},
#  {'acceptations': 16,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 45.0,
#   'voeux': 62},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 5.0,
#   'voeux': 6},
#  {'acceptations': 9,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 42.0,
#   'voeux': 75},
#  {'acceptations': 11,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Langues et littÃ©ratures Ã©trangÃ¨res',
#   'propositions_d_admissions': 38.0,
#   'voeux': 43},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 8.0,
#   'voeux': 28},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Pluri Lettres - Langues - Sciences humaines',
#   'propositions_d_admissions': 3.0,
#   'voeux': 5},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 1.0,
#   'voeux': 2},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Pluri Sciences de la vie, de la santÃ©, de la terre et '
#                'de l univers',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Sciences de l univers, de la terre, de l espace',
#   'propositions_d_admissions': 0.0,
#   'voeux': 9},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 5.0,
#   'voeux': 9},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 18.0,
#   'voeux': 52},
#  {'acceptations': 17,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 48.0,
#   'voeux': 140},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 242,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 315.0,
#   'voeux': 420},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 10.0,
#   'voeux': 26},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Electronique, GÃ©nie Ã©lectrique, EEA',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Formation gÃ©nÃ©rale aux mÃ©tiers de l ingÃ©nieur',
#   'propositions_d_admissions': 3.0,
#   'voeux': 5},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 10.0,
#   'voeux': 18},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences de la vie, de la santÃ©, de la terre et '
#                'de l univers',
#   'propositions_d_admissions': 0.0,
#   'voeux': 5},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences Ã©conomiques - Gestion',
#   'propositions_d_admissions': 7.0,
#   'voeux': 10},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de la vie, biologie, santÃ©',
#   'propositions_d_admissions': 5.0,
#   'voeux': 16},
#  {'acceptations': 3,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences et technologies industrielles',
#   'propositions_d_admissions': 6.0,
#   'voeux': 12},
#  {'acceptations': 48,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 87.0,
#   'voeux': 218},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'DEUST',
#   'propositions_d_admissions': 2.0,
#   'voeux': 9},
#  {'acceptations': 283,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Arts',
#   'propositions_d_admissions': 645.0,
#   'voeux': 911},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 11,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 53.0,
#   'voeux': 82},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 5.0,
#   'voeux': 12},
#  {'acceptations': 10,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 31.0,
#   'voeux': 87},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de la vie, biologie, santÃ©',
#   'propositions_d_admissions': 2.0,
#   'voeux': 6},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences et technologies industrielles',
#   'propositions_d_admissions': 3.0,
#   'voeux': 13},
#  {'acceptations': 149,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences juridiques',
#   'propositions_d_admissions': 295.0,
#   'voeux': 435},
#  {'acceptations': 5,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 36.0,
#   'voeux': 927},
#  {'acceptations': 130,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 224.0,
#   'voeux': 731},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 2.0,
#   'voeux': 50},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 1.0,
#   'voeux': 2},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Sciences et technologies industrielles',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 1.0,
#   'voeux': 10},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 4.0,
#   'voeux': 10},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'CPGE S',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Autres formations',
#   'propositions_d_admissions': 2.0,
#   'voeux': 13},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 23,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 33.0,
#   'voeux': 42},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Formation gÃ©nÃ©rale aux mÃ©tiers de l ingÃ©nieur',
#   'propositions_d_admissions': 2.0,
#   'voeux': 12},
#  {'acceptations': 9,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 36.0,
#   'voeux': 51},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 2.0,
#   'voeux': 2},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Langues',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 4.0,
#   'voeux': 6},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 0.0,
#   'voeux': 3},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 5.0,
#   'voeux': 7},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de l univers, de la terre, de l espace',
#   'propositions_d_admissions': 15.0,
#   'voeux': 53},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 1.0,
#   'voeux': 6},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences religieuses',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 13,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 51.0,
#   'voeux': 67},
#  {'acceptations': 5,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 10.0,
#   'voeux': 59},
#  {'acceptations': 37,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 74.0,
#   'voeux': 218},
#  {'acceptations': 31,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'D.E sanitaire',
#   'propositions_d_admissions': 51.0,
#   'voeux': 137},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence GÃ©nie civil',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences de l information et de la communication',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences et technologies industrielles',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences juridiques',
#   'propositions_d_admissions': 2.0,
#   'voeux': 4},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences Ã©conomiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 2.0,
#   'voeux': 9},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences juridiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'BTS Agricole',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'DCG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Electronique, GÃ©nie Ã©lectrique, EEA',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Pluri Lettres - Langues - Sciences humaines',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences de l univers, de la terre, de l espace',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences de la vie, biologie, santÃ©',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'PASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'D.E sanitaire',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'DEUST',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Langues et littÃ©ratures Ã©trangÃ¨res',
#   'propositions_d_admissions': 13.0,
#   'voeux': 18},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 2.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences religieuses',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 31,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'BUT Production',
#   'propositions_d_admissions': 72.0,
#   'voeux': 151},
#  {'acceptations': 17,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 50.0,
#   'voeux': 107},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 2.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'CUPGE',
#   'propositions_d_admissions': 0.0,
#   'voeux': 4},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 45},
#  {'acceptations': 334,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 368.0,
#   'voeux': 392},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Electronique, GÃ©nie Ã©lectrique, EEA',
#   'propositions_d_admissions': 2.0,
#   'voeux': 2},
#  {'acceptations': 15,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 47.0,
#   'voeux': 58},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 4.0,
#   'voeux': 70},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 35.0,
#   'voeux': 42},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 15.0,
#   'voeux': 86},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 9.0,
#   'voeux': 14},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 4.0,
#   'voeux': 4},
#  {'acceptations': 48,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence STAPS',
#   'propositions_d_admissions': 117.0,
#   'voeux': 228},
#  {'acceptations': 11,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de l univers, de la terre, de l espace',
#   'propositions_d_admissions': 65.0,
#   'voeux': 212},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences religieuses',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 101,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'PASS',
#   'propositions_d_admissions': 145.0,
#   'voeux': 293},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 1.0,
#   'voeux': 10},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 5.0,
#   'voeux': 26},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'DCG',
#   'propositions_d_admissions': 2.0,
#   'voeux': 13},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 7.0,
#   'voeux': 151},
#  {'acceptations': 1068,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 1151.0,
#   'voeux': 1209},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'BTS Agricole',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 3.0,
#   'voeux': 6},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'CUPGE',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 10,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 13.0,
#   'voeux': 15},
#  {'acceptations': 368,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Arts',
#   'propositions_d_admissions': 898.0,
#   'voeux': 1388},
#  {'acceptations': 1282,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 3771.0,
#   'voeux': 4533},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 2.0,
#   'voeux': 7},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 4},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
# ...
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 3,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 11.0,
#   'voeux': 18},
#  {'acceptations': 120,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Arts',
#   'propositions_d_admissions': 291.0,
#   'voeux': 367},
#  {'acceptations': 3,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 18.0,
#   'voeux': 21},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 11},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 1.0,
#   'voeux': 8},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 44,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 98.0,
#   'voeux': 192},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 23.0,
#   'voeux': 34},
#  {'acceptations': 19,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'BTS Agricole',
#   'propositions_d_admissions': 24.0,
#   'voeux': 42},
#  {'acceptations': 3,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 4.0,
#   'voeux': 10},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 4.0,
#   'voeux': 23},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'CUPGE',
#   'propositions_d_admissions': 0.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 11},
#  {'acceptations': 636,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 773.0,
#   'voeux': 878},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Arts',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Pluri Lettres - Langues - Sciences humaines',
#   'propositions_d_admissions': 2.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Pluri Sciences Ã©conomiques - Gestion',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence GÃ©nie civil',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences Ã©conomiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'CUPGE',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'DEUST',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence MÃ©canique, GÃ©nie mÃ©canique, IngÃ©nierie mÃ©canique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Pluri Sciences de la vie, de la santÃ©, de la terre et '
#                'de l univers',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Pluri Sciences fondamentales et applications',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences de l information et de la communication',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'BUT Production',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'BTS Agricole',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': "Ecoles d'ingÃ©nieurs",
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 7.0,
#   'voeux': 9},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 15.0,
#   'voeux': 42},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 1.0,
#   'voeux': 19},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 19},
#  {'acceptations': 11,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 25.0,
#   'voeux': 44},
#  {'acceptations': 5,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 12.0,
#   'voeux': 24},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 4.0,
#   'voeux': 8},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences juridiques',
#   'propositions_d_admissions': 18.0,
#   'voeux': 31},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences Ã©conomiques',
#   'propositions_d_admissions': 4.0,
#   'voeux': 7},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 15.0,
#   'voeux': 18},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'PASS',
#   'propositions_d_admissions': 22.0,
#   'voeux': 60},
#  {'acceptations': 8,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 16.0,
#   'voeux': 59},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Autres formations',
#   'propositions_d_admissions': 15.0,
#   'voeux': 53},
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
from langchain_community.document_loaders import JSONLoader

loader = JSONLoader(
    file_path="../parcoursup/parcoursup_data.json",
    jq_schema=".[]",
    text_content=False
)

documents = loader.load()
pprint(documents[0])
# Out:
# Document(metadata={'source': 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\parcoursup\\parcoursup_data.json', 'seq_num': 1}, page_content='{"annee_du_bac": 2021, "doublette": "Art,Art", "formation": "Licence Chimie", "voeux": 0, "propositions_d_admissions": 0, "acceptations": 0}')

# %% [markdown]
# ### Test: loading a single XML file

# %%
from bs4 import BeautifulSoup

with open('../onisep/Onisep_Fiches_Formations.xml', 'r', encoding="utf-8") as f:
    data = f.read()

bs_data = BeautifulSoup(data, 'xml')

print(bs_data.prettify()[:500])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <formations xmlns:exsl="http://exslt.org/common">
#  <formation>
#   <identifiant>
#    FOR.1000
#   </identifiant>
#   <code_scolarite>
#    16X20003
#   </code_scolarite>
#   <libelle_complet>
#    mastère spé. management de la qualité, de la sécurité et de l'environnement
#   </libelle_complet>
#   <sigle/>
#   <libelle_generique/>
#   <libelle_specifique/>
#   <type_option/>
#   <type_Formation>
#    <type_formation_sigle>
#     mastère spé.
#    </type_formation_sigle>
#    <type_formation

# %%
from langchain_community.document_loaders import UnstructuredXMLLoader
from pprint import pprint

loader = UnstructuredXMLLoader('../onisep/Onisep_Fiches_Formations.xml')

documents = loader.load()

print(documents[0].page_content[:500])
# Out:
# FOR.1000
#
# 16X20003
#
# mastère spé. management de la qualité, de la sécurité et de l'environnement
#
# mastère spé.
#
# MASTERE SPE
#
# mastère spécialisé
#
# "1 an"
#
# https://www.francecompetences.fr/recherche/rncp/37084/
#
# 200
#
# Spécialités pluritechnologiques de la production
#
# R
#
# Contrôle, prévention, entretien
#
# niveau 7
#
# REF.423
#
# bac + 6
#
# 16X
#
# Label de la Conférence des grandes écoles (CGE)
#
# Formation inscrite au RNCP
#
# MET.878
#
# chargé/e hygiène sécurité environnement (HSE)
#
# chargée hygiène sécurité environnem

# %% [markdown]
# ### Converting XML files to JSON files
#
# The layout of Document objects loaded from XML files is too different from JSON files, and less well structured, so the MistralAI API cannot later embed them into the vector store

# %%
import json
import xmltodict

def convert_xml_to_json(xml_file: str, json_file: str):
    try:
        with open(xml_file, 'r', encoding='utf-8') as f:
            xml_content = f.read()

        data_dict = xmltodict.parse(xml_content)

        formations = data_dict.get("formations", {})
        if isinstance(formations, dict):
            formations = formations.get("formation", [])
        else:
            formations = []

        processed_formations = []

        for formation in formations:
            processed_entry = {}

            # Direct string fields
            processed_entry["identifiant"] = formation["identifiant"] if "identifiant" in formation else None
            processed_entry["libelle_complet"] = formation["libelle_complet"] if "libelle_complet" in formation else None
            processed_entry["duree_formation"] = formation["duree_formation"].strip('"') if "duree_formation" in formation else None
            processed_entry["url"] = formation["url"] if "url" in formation else None
            processed_entry["niveau_certification"] = formation["niveau_certification"] if "niveau_certification" in formation else None
            processed_entry["poursuites_etudes"] = formation["poursuites_etudes"] if "poursuites_etudes" in formation else None
            processed_entry["publications"] = formation["publications"] if "publications" in formation else None

            # Nested structures
            if "type_Formation" in formation and isinstance(formation["type_Formation"], dict):
                processed_entry["type_Formation"] = formation["type_Formation"].get("type_formation_libelle", None)
            else:
                processed_entry["type_Formation"] = None

            if "niveau_etudes" in formation and isinstance(formation["niveau_etudes"], dict):
                processed_entry["niveau_etudes"] = formation["niveau_etudes"].get("libelle", None)
            else:
                processed_entry["niveau_etudes"] = None

            if "nsf_discipline" in formation and isinstance(formation["nsf_discipline"], dict):
                processed_entry["nsf_discipline"] = formation["nsf_discipline"].get("NSF_discipline_libelle", None)
            else:
                processed_entry["nsf_discipline"] = None

            if "nature_certificat" in formation and isinstance(formation["nature_certificat"], dict):
                certif = formation["nature_certificat"].get("libelle_nature_certificat", None)
                processed_entry["nature_certificat"] = ", ".join(certif) if isinstance(certif, list) else certif
            else:
                processed_entry["nature_certificat"] = None

            # Handling "metiers_formation" properly
            processed_entry["metiers_formation"] = []
            if "metiers_formation" in formation and isinstance(formation["metiers_formation"], dict):
                metiers = formation["metiers_formation"].get("metier", [])

                if isinstance(metiers, dict):  # If there is only one "metier"
                    metiers = [metiers]

                for metier in metiers:
                    metier_data = {"nom_metier": metier.get("nom_metier", None), "synonymes": []}

                    if "synonymes" in metier and isinstance(metier["synonymes"], dict):
                        synonyms = metier["synonymes"].get("synonyme", [])

                        if isinstance(synonyms, dict):  # If there is only one synonym
                            synonyms = [synonyms]

                        metier_data["synonymes"] = [syn.get("nom_metier") for syn in synonyms if isinstance(syn, dict)]

                    processed_entry["metiers_formation"].append(metier_data)

            processed_formations.append(processed_entry)

        with open(json_file, 'w', encoding='utf-8') as f:
            json.dump(processed_formations, f, ensure_ascii=False, indent=4)

        print(f"Conversion réussie : '{xml_file}' → '{json_file}'")

    except Exception as e:
        print(f"Erreur lors de la conversion : {e}")

# Exemple d'utilisation
convert_xml_to_json("../onisep/Onisep_Fiches_Formations.xml", "../onisep/Onisep_Fiches_Formations.json")
# Out:
# Conversion réussie : '../onisep/Onisep_Fiches_Formations.xml' → '../onisep/Onisep_Fiches_Formations.json'

# %%
import json
import xmltodict

def convert_xml_to_json_2(xml_file: str, json_file: str):
    try:
        with open(xml_file, 'r', encoding='utf-8') as f:
            xml_content = f.read()

        data_dict = xmltodict.parse(xml_content)

        metiers = data_dict.get("metiers", {})
        if isinstance(metiers, dict):
            metiers = metiers.get("metier", [])
        else:
            metiers = []

        processed_metiers = []

        for metier in metiers:
            processed_entry = {}

            # Direct string fields
            processed_entry["identifiant"] = metier.get("identifiant")
            processed_entry["nom_metier"] = metier.get("nom_metier")
            processed_entry["libelle_feminin"] = metier.get("libelle_feminin")
            processed_entry["libelle_masculin"] = metier.get("libelle_masculin")
            processed_entry["competences"] = metier.get("competences")
            processed_entry["condition_travail"] = metier.get("condition_travail")
            processed_entry["nature_travail"] = metier.get("nature_travail")
            processed_entry["acces_metier"] = metier.get("acces_metier")
            processed_entry["vie_professionnelle"] = metier.get("vie_professionnelle")
            processed_entry["accroche_metier"] = metier.get("accroche_metier")

            # Nested structures
            if "romesV3" in metier and isinstance(metier["romesV3"], dict):
                processed_entry["romesV3"] = metier["romesV3"].get("romesV3")
            else:
                processed_entry["romesV3"] = None

            if "niveau_acces_min" in metier and isinstance(metier["niveau_acces_min"], dict):
                processed_entry["niveau_acces_min"] = metier["niveau_acces_min"].get("libelle")
            else:
                processed_entry["niveau_acces_min"] = None

            # Deep-nested structures

            # Traitement des synonymes
            processed_entry["synonymes"] = []
            if "synonymes" in metier and isinstance(metier["synonymes"], dict):
                synonymes = metier["synonymes"].get("synonyme", [])
                if isinstance(synonymes, dict):  # Si il n'y a qu'un "synonyme"
                    synonymes = [synonymes]
                for synonyme in synonymes:
                    synonyme_data = {"nom_metier": synonyme.get("nom_metier")}
                    processed_entry["synonymes"].append(synonyme_data)

            # Traitement des statuts
            processed_entry["statuts"] = []
            if "statuts" in metier and isinstance(metier["statuts"], dict):
                statuts = metier["statuts"].get("statut", [])
                if isinstance(statuts, dict):  # Si il n'y a qu'un "statut"
                    statuts = [statuts]
                for statut in statuts:
                    statut_data = {"libelle": statut.get("libelle")}
                    processed_entry["statuts"].append(statut_data)

            # Traitement des metiers_associes
            processed_entry["metiers_associes"] = []
            if "metiers_associes" in metier and isinstance(metier["metiers_associes"], dict):
                metiers_associes = metier["metiers_associes"].get("metier_associe", [])
                if isinstance(metiers_associes, dict):  # Si il n'y a qu'un "metier_associe"
                    metiers_associes = [metiers_associes]
                for metier_associe in metiers_associes:
                    metier_associe_data = {"libelle": metier_associe.get("libelle")}
                    processed_entry["metiers_associes"].append(metier_associe_data)

            # Traitement des formations_min_requise
            processed_entry["formations_min_requise"] = []
            if "formations_min_requise" in metier and isinstance(metier["formations_min_requise"], dict):
                formations_min_requise = metier["formations_min_requise"].get("formation_min_requise", [])
                if isinstance(formations_min_requise, dict):  # Si il n'y a qu'une "formation_min_requise"
                    formations_min_requise = [formations_min_requise]
                for formation in formations_min_requise:
                    formation_data = {"libelle": formation.get("libelle")}
                    processed_entry["formations_min_requise"].append(formation_data)

            # Traitement des secteurs_activite
            processed_entry["secteurs_activite"] = []
            if "secteurs_activite" in metier and isinstance(metier["secteurs_activite"], dict):
                secteurs_activite = metier["secteurs_activite"].get("secteur_activite", [])
                if isinstance(secteurs_activite, dict):  # Si il n'y a qu'un "secteur_activite"
                    secteurs_activite = [secteurs_activite]
                for secteur in secteurs_activite:
                    secteur_data = {"libelle": secteur.get("libelle")}
                    processed_entry["secteurs_activite"].append(secteur_data)

            # Traitement des centres_interet
            processed_entry["centres_interet"] = []
            if "centres_interet" in metier and isinstance(metier["centres_interet"], dict):
                centres_interet = metier["centres_interet"].get("centre_interet", [])
                if isinstance(centres_interet, dict):  # Si il n'y a qu'un "centre_interet"
                    centres_interet = [centres_interet]
                for centre in centres_interet:
                    centre_data = {"libelle": centre.get("libelle")}
                    processed_entry["centres_interet"].append(centre_data)

            processed_metiers.append(processed_entry)

        with open(json_file, 'w', encoding='utf-8') as f:
            json.dump(processed_metiers, f, ensure_ascii=False, indent=4)

        print(f"Conversion réussie : '{xml_file}' → '{json_file}'")

    except Exception as e:
        print(f"Erreur lors de la conversion : {e}")

# Exemple d'utilisation
convert_xml_to_json_2("../onisep/Onisep_Fiches_Metiers.xml", "../onisep/Onisep_Fiches_Metiers.json")
# Out:
# Conversion réussie : '../onisep/Onisep_Fiches_Metiers.xml' → '../onisep/Onisep_Fiches_Metiers.json'

# %% [markdown]
# ### Loading multiple JSON files as LangChain Document objects

# %%
import os
import json
from pathlib import Path
from langchain.docstore.document import Document
from langchain_community.document_loaders import JSONLoader, UnstructuredXMLLoader

# To correct UnstructuredXMLLoader errors
# import nltk
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

def load_json_documents(file_path: str) -> list:
    """
    Load a JSON file using JSONLoader and return a list of Documents
    """
    loader = JSONLoader(
        file_path=file_path,
        jq_schema=".[]",
        text_content=False,
    )
    try:
        documents = loader.load()
        print(f"[JSON] Loaded file: {file_path} ({len(documents)} document(s))")
        return documents
    except Exception as e:
        print(f"Error while loading JSON file {file_path} : {e}")
        return []

# def load_xml_documents(file_path: str) -> list:
#    """
#    Load an XML file using UnstructuredXMLLoader and return a list of Documents
#    """
#    loader = UnstructuredXMLLoader(file_path)
#    try:
#        documents = loader.load()
#        print(f"[XML] Loaded file: {file_path} ({len(documents)} document(s))")
#        return documents
#    except Exception as e:
#        print(f"Error while loading XML file {file_path} : {e}")
#        return []

def load_documents(file_paths: list) -> list:
    """
    For each file in the list, we determine its extension and call the appropriate loader
    (JSONLoader or UnstructuredXMLLoader), and then return a complete list of Documents
    """
    documents = []
    for fp in file_paths:
        ext = Path(fp).suffix.lower()
        if ext == ".json":
            documents.extend(load_json_documents(fp))
#        elif ext == ".xml":
#            documents.extend(load_xml_documents(fp))
        else:
            print(f"Unsupported file (extension {ext}) : {fp}")
    return documents

def export_documents(documents: list):
    """
    Save the Document objects to a text file for inspection or debugging
    """
    with open("loaded_documents.txt", "w", encoding="utf-8") as f:
        for doc in documents:
            f.write(f"Source: {doc.metadata.get('source')}\n")
            f.write(f"Content:\n{doc.page_content}\n\n---\n\n")
    
    print("Documents saved to 'loaded_documents.txt'")

# %%
# List of JSON and XML files to load
file_list = [
    # DONE:
    # "../parcoursup/parcoursup_data.json",
    # "../mon_master/monmaster_data.json",
    # "../salons/salons_january.json",
    # "../salons/salons_february.json",
    # "../salons/salons_march.json",
    # "../salons/salons_may_june.json"
    # "../France_travail/Competences-themes.json",
    # "../France_travail/Francetravail Scraper debutant.json",
    # "../France_travail/Francetravail Scraper junior .json",
    # "../France_travail/Francetravail_Scraper_Global.json",
    # "../France_travail/Nombre_offres_themes.json",
    # "../mbti/mbti_jobs.json",
    # "../onisep/Onisep_Fiches_Formations.json",
    #"../onisep/Onisep_Fiches_Metiers.json",
]

# Load all the documents
all_documents = load_documents(file_list)

print(f"\nTotal number of loaded documents: {len(all_documents)}")

export_documents(all_documents)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

def dynamic_split_documents(documents, base_chunk_size=1000, min_chunks=3, max_chunks=200):
    """
    Dynamically split a list of documents into smaller chunks based on document size
    
    Parameters:
        - documents: List of LangChain Document objects
        - base_chunk_size: Default chunk size in characters
        - min_chunks: Minimum number of chunks per document
        - max_chunks: Maximum number of chunks per document
    
    Returns:
        - List of split documents
    """
    all_splits = []
    
    for doc in documents:
        doc_length = len(doc.page_content)
        
        # Dynamically adjust the chunk size:
        # - Ensure chunks are not too small by using at least `base_chunk_size`
        # - Ensure chunks are not too big by keeping at least `min_chunks` per document
        # - This balances the number and size of chunks for better retrieval
        chunk_size = max(base_chunk_size, doc_length // max_chunks)  # Prevents chunks from being too tiny
        chunk_size = min(chunk_size, doc_length // min_chunks)  # Ensures we don't have too few large chunks
        
        # Define the text splitter
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size,
            chunk_overlap=chunk_size // 5,  # 20% overlap
            add_start_index=True # Keeps track of where in the original document each chunk came from
        )
        
        # Split the document and extend the list
        splits = text_splitter.split_documents([doc])
        # print(f"Document: {doc.metadata.get('source')} | Original Length: {len(doc.page_content)} | Chunks Created: {len(splits)}")
        
        all_splits.extend(splits) # Adds all the elements in splits to all_splits, one by one
    
    print(f"\nTotal number of chunks created: {len(all_splits)}")
    return all_splits

def export_split_documents(chunks):
    """
    Save the split documents to a text file with delimiters between chunks

    Each document chunk's source and content are written to 'split_documents.txt', 
    with '---' as a separator between different chunks.

    Parameters:
        - chunks (list): A list of LangChain Document objects after splitting

    Returns:
        - File containing all split document chunks with delimiters
    """
    with open("split_documents.txt", "w", encoding="utf-8") as f:
        for i, chunk in enumerate(chunks):
            # Add delimiter before every chunk except the first one
            if i > 0:
                f.write("\n---\n\n")

            f.write(f"Source: {chunk.metadata.get('source')}\n")
            f.write(f"Content:\n{chunk.page_content}\n")

    print("Split documents saved to 'split_documents.txt'")


# Split the loaded documents
split_documents = dynamic_split_documents(all_documents)

export_split_documents(split_documents)

# %% [markdown]
# ## Storing Document splits
#
# Indexing our chunks of documents to be able to vector search over them at runtime, which entails embedding the contents of each chunk of Document into the Chroma vector store

# %%
import time

def batch_embed_documents(split_documents, vector_store, batch_size=10, sleep_time=2):
    """
    Embed Documents in batches and add them to the vector store

    Parameters:
        - split_documents (list): List of document chunks to embed
        - vector_store: The vector database where embeddings are stored
        - batch_size (int): Number of documents per batch (default is 10)
        - sleep_time (int): Time to wait (in seconds) between batches to avoid API rate limits (default is 2)
    
    Returns:
        - None
    """
    for i in range(0, len(split_documents), batch_size):
        batch = [chunk for chunk in split_documents[i:i + batch_size]]

        try:
            document_ids = vector_store.add_documents(documents=batch)
            print(f"Batch {i // batch_size + 1}: {document_ids[:3]}")
        except Exception as e:
            print(f"Error in batch {i // batch_size + 1}: {e}")

        time.sleep(sleep_time)  # Pause to prevent API rate limiting


batch_embed_documents(split_documents, vector_store)

# %%
# Number of Document objects stored in our vector store
print("Number of Documents:")
print(vector_store._collection.count())

# IDs of the first 10 Documents stored in our vector store
print("\nIDs of the first 10 Documents stored in the vector store:")
print(vector_store._collection.get()["ids"][:10])

# Test query on our vector store
query = "gouvernement"
print(f'\nQuerying "{query}" on our vector store:')
results = vector_store.similarity_search(query, k=3)
for doc in results:
    print(doc.page_content)
# Out:
# Number of Documents:
# 160472
#
# IDs of the first 10 Documents stored in the vector store:
# ['e4e290e7-3ad0-4d26-8c13-078ae83824f4', '719fe31e-7cbd-4152-9cf2-5262553ffa01', '0493492c-a637-4bcb-a4f7-2f597daca379', 'e4ea8808-f8f7-4690-9304-bf222d227ee7', '5e5ee20a-1dac-4b75-aa25-86c65dcf4257', 'ff2bfd8a-083f-4d48-a908-829cac595dd7', '818fcd79-c451-4f65-bfa0-8d1068b32c0b', 'eb59f67c-0fdd-4435-b1da-7251d52c1983', '6a2ebf7c-ca2c-4706-b176-1c8514bd7059', 'd7669c3a-e27e-4c6d-8cac-ad2e666db1e9']
#
# Querying "gouvernement" on our vector store:
# G\u00e9opolitique et Sciences politiques", "formation": "Formations
# G\u00e9opolitique et Sciences politiques", "formation": "Formations
# G\u00e9opolitique et Sciences politiques", "formation": "Formations

# %% [markdown]
# ## Embedding the documents and persisting the vector store to a ChromaDB (vectorial) database

# %%
import time
import chromadb
from chromadb import PersistentClient

# Define database path & collection name
DB_PATH = "./final_chroma_db"  
COLLECTION_NAME = "final_vector_store_collection"  
BATCH_SIZE = 50
DELAY = 5

# 1️⃣ Connect to ChromaDB and create a new collection
client = PersistentClient(path=DB_PATH)
try:
    client.delete_collection(name=COLLECTION_NAME)
    print(f"🗑️ Old collection '{COLLECTION_NAME}' deleted.")
except Exception:
    pass  # If it doesn't exist, no issue
collection = client.get_or_create_collection(name=COLLECTION_NAME)
print(f"✅ New collection '{COLLECTION_NAME}' created in '{DB_PATH}'.")

# 2️⃣ Load documents from the vector store
stored_data = vector_store.get()

if "documents" not in stored_data or not stored_data["documents"]:
    raise ValueError("❌ ERROR: No documents found in the vector store!")

documents = stored_data["documents"]
num_documents = len(documents)
print(f"📂 {num_documents} documents found in the vector store.")

# 3️⃣ Generate embeddings in batches
print("🔄 Generating embeddings for documents in batches...")
generated_embeddings = []

for i in range(0, num_documents, BATCH_SIZE):
    batch_docs = documents[i:i + BATCH_SIZE]
    try:
        batch_embeddings = embeddings.embed_documents(batch_docs)
        generated_embeddings.extend(batch_embeddings)
        print(f"✅ Processed batch {i // BATCH_SIZE + 1}/{num_documents // BATCH_SIZE + 1}")
    except Exception as e:
        print(f"❌ Error processing (generating embedding) batch {i // BATCH_SIZE + 1}: {e}")
    time.sleep(DELAY)  # Increased delay to avoid rate limiting

# Double-check length consistency
num_embeddings = len(generated_embeddings)
if len(stored_data["ids"]) != num_documents or num_embeddings != num_documents:
    print("❌ ERROR: Mismatch in lengths! Ensure 'ids', 'embeddings', and 'documents' have the same size.")

print(f"✅ Generated {num_embeddings} embeddings.")

# 4️⃣ Insert all embeddings & documents into ChromaDB
print("📥 Storing documents & embeddings in ChromaDB...")

for i in range(0, num_documents, BATCH_SIZE):
    batch_ids = stored_data["ids"][i:i + BATCH_SIZE]
    batch_embeddings = generated_embeddings[i:i + BATCH_SIZE]
    batch_documents = documents[i:i + BATCH_SIZE]
    batch_metadatas = stored_data.get("metadatas", [None] * num_documents)[i:i + BATCH_SIZE]

    # Check if metadatas are provided and have the correct length
    if batch_metadatas == [None] * len(batch_documents):
        print("⚠️ Warning: No metadata provided for this batch.")
    elif len(batch_metadatas) != len(batch_documents):
        print("❌ ERROR: Mismatch in lengths between metadatas and documents!")

    try:
        collection.add(
            ids=batch_ids,
            embeddings=batch_embeddings,
            documents=batch_documents,
            metadatas=batch_metadatas
        )
    except Exception as e:
        print(f"❌ Error processing (inserting embedding) batch {i // BATCH_SIZE + 1}: {e}")

    time.sleep(DELAY)  # Add delay between batches

print(f"🎉 Successfully stored {num_documents} documents & embeddings in '{DB_PATH}/{COLLECTION_NAME}'!")

# %%
import chromadb
from chromadb import PersistentClient

# 1️⃣ Connect to the existing ChromaDB instance
db_path = "./final_chroma_db"
collection_name = "final_vector_store_collection"

client = PersistentClient(path=db_path)
collection = client.get_or_create_collection(name=collection_name)
print(f"✅ Connected to ChromaDB collection '{collection_name}' in '{db_path}'.")

# 2️⃣ Load stored embeddings from ChromaDB
stored_data = collection.get()

# 3️⃣ Check how many embeddings are loaded
num_loaded = len(stored_data["ids"])
print(f"🔍 Loaded {num_loaded} embeddings from ChromaDB.")
# Out:
# ✅ Connected to ChromaDB collection 'final_vector_store_collection' in './final_chroma_db'.
# 🔍 Loaded 104750 embeddings from ChromaDB.

# %% [markdown]
# 📌 Where to Place It?
# 💡 Replace any code that loads vector_store.get() with this script instead!
# If you previously used:
#
# stored_data = vector_store.get()
#
# ❌ Remove it and replace it with:
#
# stored_data = collection.get()
#
# This way, every time your script runs, it automatically pulls data from ChromaDB instead of the local vector store. 🚀

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain import hub

def build_retrieval_chain(vector_store, llm, k=5):
    """
    Build a retrieval chain using a given vector store and LLM
    
    Parameters:
        - vector_store: The vector store containing document embeddings
        - llm: The language model to generate responses
        - k: Number of most relevant document chunks to retrieve (default is 5)
    
    Returns:
        - retrieval_chain: A LangChain retrieval chain object.
    """
    # Create a retriever from the vector store
    retriever = vector_store.as_retriever(search_kwargs={"k": k})
    
    # Load a pre-defined prompt template for retrieval-based Q&A
    retrieval_chat_prompt = hub.pull("langchain-ai/retrieval-qa-chat")
    
    # Create a document combination chain
    combine_docs_chain = create_stuff_documents_chain(llm, retrieval_chat_prompt)
    
    # Create and return the retrieval chain
    return create_retrieval_chain(retriever, combine_docs_chain)

# %% [markdown]
# ## LLM Prompt-Engineering

# %% [markdown]
# In this part, we implement an advanced AI chatbot using LangChain and LangGraph.
# It integrates :
# - RAG (Retrieval-Augmented Generation) with source display
# - Streaming responses for enhanced user experience
# - Conversational memory for tracking interactions

# %%
#  Importation des bibliothèques
import os
import json
import getpass
import requests

from langchain_mistralai.chat_models import ChatMistralAI
from langgraph.graph import START, MessagesState, StateGraph
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.prompts import PipelinePromptTemplate

# %% [markdown]
# ### Prompt definition

# %%
prompt_principal = ChatPromptTemplate.from_template(
    """
    Tu es **Crystal Bot**, un assistant intelligent d'orientation professionnelle.
    Tu dois fournir des réponses basées sur les informations récupérées.
    
    Ton objectif est d'aider chaque utilisateur à **clarifier son avenir** en lui proposant **des conseils sur-mesure et motivants**.

    **Contexte pertinent issu de la base de connaissances :** 
    {context}
    
    ➤ **Adapte-toi** à l’utilisateur
    ➤ Si l’utilisateur semble **indécis ou curieux**, **propose des pistes d’exploration** (salons, témoignages, mentors, forums spécialisés).  
    ➤ **Si la personnalité est mentionnée mais non connue**, **invite subtilement à découvrir son MBTI** sans forcer.  
    ➤ **Si l’utilisateur cherche à comparer plusieurs options**, **aide-le à peser le pour et le contre** avec des arguments personnalisés.  
    ➤ Ajoute parfois une touche légère de mystère ou de vision d’avenir, sans trop en faire.  

    **Fournis une réponse détaillée, et motivante.**  
    Sois précis mais laisse de la place à l’exploration !
    """
)

topic_prompt = PromptTemplate.from_template(
    """
    Analyse la question et identifie son domaine principal :
    Question: {input}
    """
)

intent_prompt = PromptTemplate.from_template(
    """
    Analyse la question et identifie l’intention principale de l’utilisateur :
    Question: {input}
    """
)

chatbot_prompt = PromptTemplate.from_template(
    """
    L'utilisateur a demandé : {input}.
    Domaine détecté : {topic} (caché à l'utilisateur)
    Intention détectée : {intent} (caché à l'utilisateur)
    
    ➤ **Si l'intention est "Métiers"** :
        - Propose des métiers adaptés et innovants.
        - Donne une vision inspirante et dynamique.
        
    ➤ **Si l'intention est "Formations"** :
        - Propose des formations adaptées et alternatives.
        - Explique les opportunités de spécialisation.

    ➤ **Si l'intention est "Salaire"** :
        - Explique les différences selon l’expérience et le secteur.
        - Évoque les tendances actuelles.

    ➤ **Si l'intention est "Offres d'emploi"** :
        - Donne des conseils personnalisés sur la recherche d’emploi.
        - Propose une approche proactive.

    ➤ **Si l'intention est "Parcoursup"** :
        - Explique comment optimiser son dossier et lettre de motivation.

    ➤ **Si l'intention est "Autre"** :
        - Propose une réponse originale en fonction du contexte.
    """
)

closing_prompt = PromptTemplate.from_template(
    """
    J’espère que cette réponse **t’a aidé à y voir plus clair !** 🔮  
    **As-tu d’autres questions ?** Je suis là pour explorer toutes les possibilités avec toi.  
    """
)

# %% [markdown]
# ### Setting up conversation memory

# %%
# Mise en place de la mémoire conversationnelle
memory = MemorySaver()
workflow = StateGraph(state_schema=MessagesState)

def call_model(state: MessagesState):
    """Appelle le modèle avec historique de conversation"""
    response = llm.invoke(state["messages"])
    return {"messages": response}

workflow.add_edge(START, "model")
workflow.add_node("model", call_model)
chatbot = workflow.compile(checkpointer=memory)

# %% [markdown]
# ## Creating the retrieval chain with LangChain
#
# Creating a retrieval chain that, based on a user question, will retrieve relevant Documents from Chroma and provide them in context to the MistralAI language model to generate an informed answer

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain import hub

def build_retrieval_chain(vector_store, llm, k=5):
    """
    Build a retrieval chain using a given vector store and LLM
    
    Parameters:
        - vector_store: The vector store containing document embeddings
        - llm: The language model to generate responses
        - k: Number of most relevant document chunks to retrieve (default is 5)
    
    Returns:
        - retrieval_chain: A LangChain retrieval chain object.
    """
    # Create a retriever from the vector store
    retriever = vector_store.as_retriever(search_kwargs={"k": k})
    
    # Load a pre-defined prompt template for retrieval-based Q&A
    retrieval_chat_prompt = hub.pull("langchain-ai/retrieval-qa-chat")
    
    # Create a document combination chain
    combine_docs_chain = create_stuff_documents_chain(llm, retrieval_chat_prompt)
    
    # Create and return the retrieval chain
    return create_retrieval_chain(retriever, combine_docs_chain)

def retrieve_and_format_context(user_query, vector_store, llm):
    """Retrieve documents from vector store and format the context"""
    retrieval_chain = build_retrieval_chain(vector_store, llm)
    retrieved_docs = retrieval_chain.invoke({"input": user_query})

    documents = retrieved_docs["context"]

    formatted_context = "\n".join([doc.page_content for doc in documents])
    sources = [doc.metadata.get("source", "Unknown source") for doc in documents]

    return formatted_context, sources

# %% [markdown]
# ## Building a full ChatBot response

# %%
def generate_response(user_query, vector_store, llm):
    """Generate an optimized response with CrystalBot and keep the history"""

    context, sources = retrieve_and_format_context(user_query, vector_store, llm)
    
    global conversation_history  # Utilisation d'une variable distincte pour stocker les messages

    # Charger l'historique des messages de manière locale
    past_messages = conversation_history if 'conversation_history' in globals() else []  

    # **🔹 Étape 1 : Détection du domaine / topic**
    topic_output = topic_prompt.format(input=user_query)

    # **🔹 Étape 2 : Détection de l’intention utilisateur**
    intent_output = intent_prompt.format(input=user_query)
    if not intent_output:
        intent_output = "Autre"

    # **🔹 Étape 3 : Génération de la réponse principale**
    chatbot_prompt_hidden = chatbot_prompt.format(
        input=user_query, 
        topic=topic_output, 
        intent=intent_output,
        context=context,
    )

    chatbot_output = chatbot_prompt_hidden.replace(topic_output, "").replace(intent_output, "")

    # **🔹 Étape 4 : Génération des suggestions d’exploration selon l’intention détectée**
    exploration_suggestions = ""

    if "Métiers" in intent_output:
        exploration_suggestions += """
        **🌍 Pour aller plus loin :**  
        - 🔍 **Découvre des métiers similaires** via des plateformes comme Onisep ou Studyrama.  
        - 🎭 **Participe à des salons professionnels** et rencontres avec des experts du domaine.  
        - 👥 **Échange avec des professionnels** sur LinkedIn ou lors d’événements.  
        """

    if "Formations" in intent_output or "Parcoursup" in intent_output:
        exploration_suggestions += """
        **📚 Pour approfondir ton parcours :**  
        - 🎤 **Découvre les parcours d’anciens étudiants** via des témoignages en ligne.  
        - 🔎 **Explore les formations en alternance** et internationales.  
        - 🏫 **Assiste aux journées portes ouvertes** des écoles et universités.  
        """

    if "Salaire" in intent_output:
        exploration_suggestions += """
        **💰 Pour mieux comprendre les salaires et évolutions de carrière :**  
        - 📊 **Consulte des études de rémunération** sur Glassdoor et l’APEC.  
        - 📈 **Analyse les évolutions de carrière possibles** en fonction de ton secteur.  
        """

    if "Offres d'emploi" in intent_output:
        exploration_suggestions += """
        **📝 Pour trouver des opportunités professionnelles :**  
        - 🔍 **Consulte des plateformes spécialisées** comme Indeed ou Pôle Emploi.  
        - 📩 **Optimise ton CV et ta lettre de motivation** pour te démarquer.  
        """

    if "Les deux" in intent_output:
        exploration_suggestions += """
        **🌟 Pour lier formations et métiers :**  
        - 📚 **Découvre les formations qui recrutent le plus**.  
        - 👀 **Explore les tendances de recrutement dans ton secteur**.  
        """

    if "Autre" in intent_output:
        exploration_suggestions += """
        **🔍 Explorons d’autres pistes !**  
        - 🤔 **Précise un peu plus ta demande**, veux-tu parler de reconversion, d’entrepreneuriat, d’études à l’étranger ?  
        - 💡 **Inspiration** : Parfois, explorer d’autres secteurs peut ouvrir des portes inattendues.  
        - 🔎 **Découvre des parcours inspirants** : interviews, conférences, podcasts sur des choix de carrière atypiques.  
        """

    # **🔹 Étape 5 : Conclusion dynamique**
    closing_output = closing_prompt.format()

    # ✅ **Ajout d’une introduction engageante pour la toute première réponse**
    intro_message = f"""
    Bonjour ! 😊  

    Je suis **Crystal Bot**, ton conseiller d'orientation professionnelle. 🔮✨  
    Mon objectif est de **t’aider à clarifier ton avenir** en te proposant des pistes adaptées et personnalisées.  
    Voici quelques idées et conseils pour t’aider à avancer :  
    """

    # ✅ **Création du message final à envoyer au modèle**
    final_prompt = f"""
    {intro_message}  

    **💡 Recommandation de Crystal Bot :**  
    {chatbot_output}  

    {exploration_suggestions}  

    {closing_output}  
    """

    # ✅ **Ajout du message dans l'historique**
    messages = past_messages + [HumanMessage(content=final_prompt)]

    # ✅ **Envoi de la requête complète au modèle**
    response = llm.invoke(messages)

    # ✅ **Mise à jour de l'historique de la conversation**
    conversation_history = messages + [response]

    return {
        "response": response.content,
        "sources": sources
    }

def refine_response(chatbot_output, user_query, llm):
    """Improve clarity and precision of response with LLM"""
    refinement_prompt = f"""
    Améliore la réponse suivante en la rendant plus précise et engageante :
    Contexte : {user_query}
    Réponse initiale : {chatbot_output}
    Réponse améliorée :
    """

    refined_response = llm.invoke([HumanMessage(content=refinement_prompt)]).content

    return refined_response

# %% [markdown]
# ## Testing the ChatBot

# %%
user_query = "Quels métiers sont accessibles après un diplôme en informatique ?"

# Tester la récupération des documents depuis ChromaDB
context, sources = retrieve_and_format_context(user_query, vector_store, llm)

print("🔹 Contexte récupéré :")
print(context)
print("\n🔹 Sources associées :")
print(sources)

# Tester la réponse initiale générée par le chatbot
initial_result = generate_response(user_query, vector_store, llm)

print("\n🔹 Réponse initiale du chatbot :")
print(initial_result["response"])
print("\n🔹 Sources utilisées :")
print(initial_result["sources"])

# 🔥 Appel de refine_response pour améliorer la réponse
refined_result = refine_response(initial_result["response"], user_query, llm)

print("\n🔹 Réponse affinée du chatbot :")
print(refined_result)
# Out:
# 🔹 Contexte récupéré :
# en informatique est surtout accessible aux dipl\u00f4m\u00e9s de niveau bac\u00a0+\u00a04, +\u00a05\u00a0. Qu'il s'agisse des \u00e9coles d'ing\u00e9nieurs ou des universit\u00e9s, ces fili\u00e8res permettent d'acqu\u00e9rir une double comp\u00e9tence technologique et manag\u00e9riale. \u00c0 compl\u00e9ter par une exp\u00e9rience professionnelle de 5 ou 6\u00a0ans minimum.</p>\n            <p>Niveau bac\u00a0+\u00a05</p>\n            <p>Master en informatique</p>\n            <p>Dipl\u00f4me d'ing\u00e9nieur</p>\n            <p>Niveau bac\u00a0+\u00a06</p>\n            <p>Mast\u00e8re sp\u00e9cialis\u00e9</p>", "vie_professionnelle": "<h3>Salaire</h3>\n            <h5>Salaire du d\u00e9butant</h5>\n            <p>2915 euros brut par mois </p>\n            <h3>Int\u00e9grer le march\u00e9 du travail</h3>\n            <h5>Recrutements \u00e0 la hausse</h5>\n            <p>Secteur priv\u00e9 ou public : le poste de chef de projet b\u00e9n\u00e9ficie de recrutements importants et
# les dipl\u00f4mes vont du bac + 2 (pour les techniciens) au bac + 5 (pour les ing\u00e9nieurs). Les jeunes dipl\u00f4m\u00e9s sont appr\u00e9ci\u00e9s et les formations en alternance sont un bon moyen de mettre un pied dans l'entreprise.</p>\n            <p>Niveau bac + 2</p>\n            <p>BTS services informatiques aux organisations (option SLAM),</p>\n            <p>Niveau bac + 3</p>\n            <p>Licence professionnelle en d\u00e9veloppement d'applications ou d\u00e9veloppement internet et intranet...</p>\n            <p>BUT informatique, statistique et informatique d\u00e9cisionnelle parcours sciences des donn\u00e9es : visualisation, conception d'outils d\u00e9cisionnels</p>\n            <p>Niveau bac + 5</p>\n            <p>Master mention informatique ax\u00e9 sur le d\u00e9veloppement d'applications</p>\n            <p>Dipl\u00f4me d'ing\u00e9nieur en informatique avec une fili\u00e8re en programmation</p>\n            <p>Dipl\u00f4me d'\u00e9cole sp\u00e9cialis\u00e9e en
# nombreux tests. Il doit en outre prendre en compte les sp\u00e9cificit\u00e9s de l'affichage sur ce type d'outils, comme la taille de l'\u00e9cran, la diversit\u00e9 des plates-formes, l'interaction limit\u00e9e... ainsi que les contraintes impos\u00e9es par le client pour lequel il travaille.</p>", "acces_metier": "<p>En dehors des formations web, les \u00e9coles d'ing\u00e9nieurs proposent des modules sp\u00e9cifiques, et les formations compl\u00e9mentaires se multiplient. Quelques \u00e9coles priv\u00e9es investissent aussi le cr\u00e9neau (H\u00e9tic, Sup'Internet... ).</p>\n            <p>Niveau bac + 2</p>\n            <p>BTS en informatique</p>\n            <p>Niveau bac + 3</p>\n            <p>Licence pro mention m\u00e9tiers de l'informatique : d\u00e9veloppement d'applications ou d\u00e9veloppement internet et intranet</p>\n            <p>BUT informatique ou M\u00e9tiers du multim\u00e9dia et de l'internet</p>\n            <p>Niveau bac + 5</p>\n            <p>Dipl\u00f4me
# soci\u00e9t\u00e9s de conseil (chez les fabricants de logiciels pour l'informatique de gestion ou l'informatique industrielle). Le d\u00e9veloppeur sera plus polyvalent dans une petite structure. Les stages ou l'apprentissage sont une bonne porte d'entr\u00e9e dans l'emploi.</p>\n            <h5>Une demande forte</h5>\n            <p>Avec l'essor du e-commerce et des applications mobiles, la demande en d\u00e9veloppeurs informatiques est tr\u00e8s forte. Attention cependant, la polyvalence est la cl\u00e9 de la dur\u00e9e. En plus des langages classiques (Java, C++...), il est pr\u00e9f\u00e9rable de ma\u00eetriser \u00e9galement les technologies pour applications mobiles (IOS et Android).</p>\n            <h5>\u00c9volutions possibles</h5>\n            <p>Le d\u00e9veloppeur informatique peut devenir chef de projet ou cadre en d\u00e9veloppement. Le milieu de l'expertise technique lui est aussi accessible en tant qu'administrateur de syst\u00e8mes, de r\u00e9seaux ou de bases de
# Qelios...) qui leur donnera les bases n\u00e9cessaires \u00e0 l'exercice du m\u00e9tier.</p>\n            <p>Niveau bac + 5</p>\n            <p>Dipl\u00f4me d'ing\u00e9nieur sp\u00e9cialis\u00e9 en informatique</p>\n            <p>Master mentions informatique, r\u00e9seaux et t\u00e9l\u00e9communications, MIAGE...</p>", "vie_professionnelle": "<h3>Salaire</h3>\n            <h5>Salaire du d\u00e9butant</h5>\n            <p>Variable en fonction du statut, de l'exp\u00e9rience et de la mission.</p>\n            <h3>Int\u00e9grer le march\u00e9 du travail</h3>\n            <h5>Employeurs multiples</h5>\n            <p>Ce m\u00e9tier \u00e9tant relativement neuf, le sp\u00e9cialiste de l'accessibilit\u00e9 num\u00e9rique est souvent consultant dans une ESN (entreprise de services du num\u00e9rique). Les entreprises font appel \u00e0 lui en tant que prestataire externe pour am\u00e9liorer leur site ou leurs applications. Il peut \u00e9galement exercer dans une agence web, en tant
#
# 🔹 Sources associées :
# ['C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json', 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json', 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json', 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json', 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json']
#
# 🔹 Réponse initiale du chatbot :
# Bonjour ! 😊
#
# Je suis **Crystal Bot**, ton conseiller d'orientation professionnelle. 🔮✨
#
# Mon objectif est de **t’aider à clarifier ton avenir** en te proposant des pistes adaptées et personnalisées. Voici quelques idées et conseils pour t’aider à avancer :
#
# ### ➤ **Métiers après un diplôme en informatique :**
#
# #### **1. Développeur Web/Full Stack :**
#
#    - **Description :** Crée et maintient des sites web et des applications web.
#    - **Compétences clés :** HTML, CSS, JavaScript, frameworks comme React, Angular, ou Vue.js.
#    - **Perspectives :** Forte demande dans tous les secteurs, possibilité de travailler à distance.
#
# #### **2. Ingénieur Logiciel :**
#
#    - **Description :** Conçoit, développe et teste des logiciels.
#    - **Compétences clés :** Langages de programmation (Python, Java, C++), développement agile, gestion de versions.
#    - **Perspectives :** Opportunités dans les startups, les grandes entreprises et les institutions publiques.
#
# #### **3. Administrateur Systèmes et Réseaux :**
#
#    - **Description :** Gère les systèmes informatiques et les réseaux d'une organisation.
#    - **Compétences clés :** Systèmes d'exploitation (Linux, Windows), sécurité réseau, virtualisation.
#    - **Perspectives :** Postes dans les entreprises de toutes tailles, opportunités de mobilité internationale.
#
# #### **4. Analyste de Données :**
#
#    - **Description :** Interprète et analyse les données pour aider à la prise de décision.
#    - **Compétences clés :** SQL, Python/R, outils de visualisation de données (Tableau, Power BI).
#    - **Perspectives :** Demande croissante dans les secteurs de la finance, de la santé et du commerce.
#
# #### **5. Cybersécurité :**
#
#    - **Description :** Protège les systèmes informatiques contre les cybermenaces.
#    - **Compétences clés :** Sécurité réseau, cryptographie, éthique hacking.
#    - **Perspectives :** Besoin urgent dans toutes les industries, opportunités de carrière en tant que consultant ou dans les forces de l'ordre.
#
# #### **6. Chef de Projet IT :**
#
#    - **Description :** Gère les projets informatiques de bout en bout.
#    - **Compétences clés :** Gestion de projet (PMP, Agile), communication, leadership.
#    - **Perspectives :** Opportunités dans les entreprises technologiques, les cabinets de conseil et les services publics.
#
# ### **Conseils supplémentaires :**
#    - **Réseautage :** Participe à des conférences, des meetups et des forums en ligne pour élargir ton réseau professionnel.
#    - **Certifications :** Obtiens des certifications reconnues (AWS, Google Cloud, Microsoft Azure) pour renforcer ton CV.
#    - **Projets Personnels :** Développe des projets personnels pour montrer tes compétences pratiques et ta passion pour le domaine.
#
# ### ➤ **Formations après un diplôme en informatique :**
#
# #### **1. Master en Informatique :**
#
#    - **Description :** Approfondis tes connaissances en informatique avec une spécialisation choisie.
#    - **Compétences clés :** Recherche avancée, développement de solutions innovantes.
#    - **Perspectives :** Opportunités dans la recherche, l'enseignement, et les postes de haut niveau dans l'industrie.
#
# #### **2. Certifications Professionnelles :**
#
#    - **Description :** Obtiens des certifications reconnues pour valider tes compétences spécifiques.
#    - **Exemples :** Certifications AWS, Google Cloud, Microsoft Azure, CISSP (Cybersecurity), PMP (Projet Management).
#    - **Perspectives :** Améliore ton employabilité et ouvre des portes vers des postes spécialisés.
#
# #### **3. MOOCs et Cours en Ligne :**
#
#    - **Description :** Suis des cours en ligne pour acquérir des compétences supplémentaires.
#    - **Exemples :** Coursera, edX, Udacity, LinkedIn Learning.
#    - **Perspectives :** Flexibilité et accessibilité, possibilité de suivre des cours à ton rythme.
#
# ### **Conseils supplémentaires :**
#    - **Stage et Alternance :** Recherche des opportunités de stage ou d'alternance pour acquérir de l'expérience pratique.
#    - **Projets Académiques :** Participe à des projets de recherche ou des concours de codage pour enrichir ton portfolio.
#
# ### ➤ **Salaires après un diplôme en informatique :**
#
# #### **1. Début de Carrière :**
#
#    - **Salaires :** Entre 30 000 et 50 000 € par an, selon le métier et la localisation.
#    - **Facteurs influents :** Niveau de diplôme, compétences techniques, secteur d'activité.
#
# #### **2. Expérience Intermédiaire :**
#
#    - **Salaires :** Entre 50 000 et 80 000 € par an.
#    - **Facteurs influents :** Expérience professionnelle, certifications, spécialisations.
#
# #### **3. Expérience Avancée :**
#
#    - **Salaires :** Entre 80 000 et 120 000 € par an, voire plus.
#    - **Facteurs influents :** Leadership, expertise reconnue, projets de grande envergure.
#
# ### **Conseils supplémentaires :**
#    - **Négociation Salariale :** Apprends à négocier ton salaire en fonction de tes compétences et de l'expérience.
#    - **Évolution de Carrière :** Pense à l'évolution de ta carrière et aux opportunités de progression salariale.
#
# ### ➤ **Recherche d'emploi après un diplôme en informatique :**
#
# #### **1. CV et Lettre de Motivation :**
#
#    - **Conseils :** Personnalise ton CV et ta lettre de motivation pour chaque poste.
#    - **Focus :** Mets en avant tes compétences techniques, tes projets personnels et tes expériences professionnelles.
#
# #### **2. Réseautage :**
#
#    - **Conseils :** Utilise LinkedIn et d'autres plateformes pour te connecter avec des professionnels du secteur.
#    - **Focus :** Participe à des événements et des meetups pour élargir ton réseau.
#
# #### **3. Entretiens :**
#
#    - **Conseils :** Prépare-toi aux questions techniques et comportementales.
#    - **Focus :** Montre ta passion pour l'informatique et ton désir d'apprendre et de grandir dans le domaine.
#
# ### **Conseils supplémentaires :**
#    - **Approche Proactive :** Sois proactif dans ta recherche d'emploi, utilise les plateformes de recrutement et les agences spécialisées.
#    - **Feedback :** Demande des retours après les entretiens pour t'améliorer continuellement.
#
# ### ➤ **Optimisation de dossier Parcoursup :**
#
# #### **1. Choix des Formations :**
#
#    - **Conseils :** Sélectionne des formations qui correspondent à tes intérêts et à tes compétences.
#    - **Focus :** Prends en compte les débouchés professionnels et les opportunités de spécialisation.
#
# #### **2. Lettre de Motivation :**
#
#    - **Conseils :** Sois clair et précis sur tes motivations et tes objectifs.
#    - **Focus :** Mets en avant tes expériences, tes compétences et tes projets personnels.
#
# #### **3. Dossier de Candidature :**
#
#    - **Conseils :** Assure-toi que ton dossier est complet et bien organisé.
#    - **Focus :** Utilise des exemples concrets pour illustrer tes compétences et tes réalisations.
#
# ### **Conseils supplémentaires :**
#    - **Prépare-toi aux Entretiens :** Apprends à te présenter de manière claire et convaincante.
#    - **Suivi :** Reste en contact avec les écoles et les formations que tu as choisies pour montrer ton intérêt.
#
# J’espère que cette réponse **t’a aidé à y voir plus clair !** 🔮
#
# **As-tu d’autres questions ?** Je suis là pour explorer toutes les possibilités avec toi.
#
# 🔹 Sources utilisées :
# ['C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json', 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json', 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json', 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json', 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\onisep\\Onisep_Fiches_Metiers.json']
#
# 🔹 Réponse affinée du chatbot :
# Bonjour ! 😊
#
# Je suis **Crystal Bot**, ton conseiller d'orientation professionnelle. 🔮✨
#
# Mon objectif est de **t'aider à clarifier ton avenir** en te proposant des pistes adaptées et personnalisées. Voici quelques idées et conseils pour t'aider à avancer :
#
# ### ➤ **Métiers après un diplôme en informatique :**
#
# #### **1. Développeur Web/Full Stack :**
#
#    - **Description :** Crée et maintient des sites web et des applications web.
#    - **Compétences clés :** HTML, CSS, JavaScript, frameworks comme React, Angular, ou Vue.js.
#    - **Perspectives :** Forte demande dans tous les secteurs, possibilité de travailler à distance.
#
# #### **2. Ingénieur Logiciel :**
#
#    - **Description :** Conçoit, développe et teste des logiciels.
#    - **Compétences clés :** Langages de programmation (Python, Java, C++), développement agile, gestion de versions.
#    - **Perspectives :** Opportunités dans les startups, les grandes entreprises et les institutions publiques.
#
# #### **3. Administrateur Systèmes et Réseaux :**
#
#    - **Description :** Gère les systèmes informatiques et les réseaux d'une organisation.
#    - **Compétences clés :** Systèmes d'exploitation (Linux, Windows), sécurité réseau, virtualisation.
#    - **Perspectives :** Postes dans les entreprises de toutes tailles, opportunités de mobilité internationale.
#
# #### **4. Analyste de Données :**
#
#    - **Description :** Interprète et analyse les données pour aider à la prise de décision.
#    - **Compétences clés :** SQL, Python/R, outils de visualisation de données (Tableau, Power BI).
#    - **Perspectives :** Demande croissante dans les secteurs de la finance, de la santé et du commerce.
#
# #### **5. Cybersécurité :**
#
#    - **Description :** Protège les systèmes informatiques contre les cybermenaces.
#    - **Compétences clés :** Sécurité réseau, cryptographie, éthique hacking.
#    - **Perspectives :** Besoin urgent dans toutes les industries, opportunités de carrière en tant que consultant ou dans les forces de l'ordre.
#
# #### **6. Chef de Projet IT :**
#
#    - **Description :** Gère les projets informatiques de bout en bout.
#    - **Compétences clés :** Gestion de projet (PMP, Agile), communication, leadership.
#    - **Perspectives :** Opportunités dans les entreprises technologiques, les cabinets de conseil et les services publics.
#
# ### **Conseils supplémentaires :**
#    - **Réseautage :** Participe à des conférences, des meetups et des forums en ligne pour élargir ton réseau professionnel.
#    - **Certifications :** Obtiens des certifications reconnues (AWS, Google Cloud, Microsoft Azure) pour renforcer ton CV.
#    - **Projets Personnels :** Développe des projets personnels pour montrer tes compétences pratiques et ta passion pour le domaine.
#
# ### ➤ **Formations après un diplôme en informatique :**
#
# #### **1. Master en Informatique :**
#
#    - **Description :** Approfondis tes connaissances en informatique avec une spécialisation choisie.
#    - **Compétences clés :** Recherche avancée, développement de solutions innovantes.
#    - **Perspectives :** Opportunités dans la recherche, l'enseignement, et les postes de haut niveau dans l'industrie.
#
# #### **2. Certifications Professionnelles :**
#
#    - **Description :** Obtiens des certifications reconnues pour valider tes compétences spécifiques.
#    - **Exemples :** Certifications AWS, Google Cloud, Microsoft Azure, CISSP (Cybersecurity), PMP (Projet Management).
#    - **Perspectives :** Améliore ton employabilité et ouvre des portes vers des postes spécialisés.
#
# #### **3. MOOCs et Cours en Ligne :**
#
#    - **Description :** Suis des cours en ligne pour acquérir des compétences supplémentaires.
#    - **Exemples :** Coursera, edX, Udacity, LinkedIn Learning.
#    - **Perspectives :** Flexibilité et accessibilité, possibilité de suivre des cours à ton rythme.
#
# ### **Conseils supplémentaires :**
#    - **Stage et Alternance :** Recherche des opportunités de stage ou d'alternance pour acquérir de l'expérience pratique.
#    - **Projets Académiques :** Participe à des projets de recherche ou des concours de codage pour enrichir ton portfolio.
#
# ### ➤ **Salaires après un diplôme en informatique :**
#
# #### **1. Début de Carrière :**
#
#    - **Salaires :** Entre 30 000 et 50 000 € par an, selon le métier et la localisation.
#    - **Facteurs influents :** Niveau de diplôme, compétences techniques, secteur d'activité.
#
# #### **2. Expérience Intermédiaire :**
#
#    - **Salaires :** Entre 50 000 et 80 000 € par an.
#    - **Facteurs influents :** Expérience professionnelle, certifications, spécialisations.
#
# #### **3. Expérience Avancée :**
#
#    - **Salaires :** Entre 80 000 et 120 000 € par an, voire plus.
#    - **Facteurs influents :** Leadership, expertise reconnue, projets de grande envergure.
#
# ### **Conseils supplémentaires :**
#    - **Négociation Salariale :** Apprends à négocier ton salaire en fonction de tes compétences et de l'expérience.
#    - **Évolution de Carrière :** Pense à l'évolution de ta carrière et aux opportunités de progression salariale.
#
# ### ➤ **Recherche d'emploi après un diplôme en informatique :**
#
# #### **1. CV et Lettre de Motivation :**
#
#    - **Conseils :** Personnalise ton CV et ta lettre de motivation pour chaque poste.
#    - **Focus :** Mets en avant tes compétences techniques, tes projets personnels et tes expériences professionnelles.
#
# #### **2. Réseautage :**
#
#    - **Conseils :** Utilise LinkedIn et d'autres plateformes pour te connecter avec des professionnels du secteur.
#    - **Focus :** Participe à des événements et des meetups pour élargir ton réseau.
#
# #### **3. Entretiens :**
#
#    - **Conseils :** Prépare-toi aux questions techniques et comportementales.
#    - **Focus :** Montre ta passion pour l'informatique et ton désir d'apprendre et de grandir dans le domaine.
#
# ### **Conseils supplémentaires :**
#    - **Approche Proactive :** Sois proactif dans ta recherche d'emploi, utilise les plateformes de recrutement et les agences spécialisées.
#    - **Feedback :** Demande des retours après les entretiens pour t'améliorer continuellement.
#
# ### ➤ **Optimisation de dossier Parcoursup :**
#
# #### **1. Choix des Formations :**
#
#    - **Conseils :** Sélectionne des formations qui correspondent à tes intérêts et à tes compétences.
#    - **Focus :** Prends en compte les débouchés professionnels et les opportunités de spécialisation.
#
# #### **2. Lettre de Motivation :**
#
#    - **Conseils :** Sois clair et précis sur tes motivations et tes objectifs.
#    - **Focus :** Mets en avant tes expériences, tes compétences et tes projets personnels.
#
# #### **3. Dossier de Candidature :**
#
#    - **Conseils :** Assure-toi que ton dossier est complet et bien organisé.
#    - **Focus :** Utilise des exemples concrets pour illustrer tes compétences et tes réalisations.
#
# ### **Conseils supplémentaires :**
#    - **Prépare-toi aux Entretiens :** Apprends à te présenter de manière claire et convaincante.
#    - **Suivi :** Reste en contact avec les écoles et les formations que tu as choisies pour montrer ton intérêt.
#
# J’espère que cette réponse **t’a aidé à y voir plus clair !** 🔮
#
# **As-tu d’autres questions ?** Je suis là pour explorer toutes les possibilités avec toi.

# %%
user_query = "hello, quels métiers conseilles-tu à quelqu'un qui aime le contact avec les gens ?"

# Tester la récupération des documents depuis ChromaDB
context, sources = retrieve_and_format_context(user_query, vector_store, llm)

# Tester la réponse initiale générée par le chatbot
initial_result = generate_response(user_query, vector_store, llm)

# 🔥 Appel de refine_response pour améliorer la réponse
refined_result = refine_response(initial_result["response"], user_query, llm)

print(refined_result)

# %%
user_query = "Je souhaite intégrer une CPGE scientifique. Peux-tu m'aider à rédiger ma lettre de motivation ?"

# Tester la récupération des documents depuis ChromaDB
context, sources = retrieve_and_format_context(user_query, vector_store, llm)

# Tester la réponse initiale générée par le chatbot
initial_result = generate_response(user_query, vector_store, llm)

# 🔥 Appel de refine_response pour améliorer la réponse
refined_result = refine_response(initial_result["response"], user_query, llm)

print(refined_result)

# %% [markdown]
# ## Alternative (with COT + refinement)

# %%
def generate_response_with_cot(user_query, vector_store, llm):
    """ Génère une réponse en utilisant Chain of Thought et le LLM """

    context, sources = retrieve_and_format_context(user_query, vector_store, llm)
    
    # Étape 1 : Identification du sujet et de l'intention
    topic_output = llm.invoke([HumanMessage(content=topic_prompt.format(input=user_query))]).content
    intent_output = llm.invoke([HumanMessage(content=intent_prompt.format(input=user_query))]).content
    
    # Étape 2 : Génération d'une réponse avec le chatbot_prompt
    chatbot_input = chatbot_prompt.format(input=user_query, topic=topic_output, intent=intent_output)
    chatbot_output = llm.invoke([HumanMessage(content=chatbot_input)]).content

    # Étape 3 : Ajout d'un message de clôture
    closing_output = llm.invoke([HumanMessage(content=closing_prompt.format())]).content

    # ✅ Correction : Retourne un dictionnaire structuré
    return {
        "response": chatbot_output + "\n" + closing_output,
        "sources": sources
    }

# %%
user_query = "Quels métiers sont accessibles après un diplôme en informatique ?"

# Tester la récupération des documents depuis ChromaDB
context, sources = retrieve_and_format_context(user_query, vector_store, llm)

# Tester la réponse initiale générée par le chatbot
initial_result = generate_response_with_cot(user_query, vector_store, llm)

# 🔥 Appel de refine_response pour améliorer la réponse
refined_result = refine_response(initial_result["response"], user_query, llm)

print("\n🔹 Réponse affinée du chatbot :")
print(refined_result)
