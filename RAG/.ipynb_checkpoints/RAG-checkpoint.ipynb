# %% [markdown]
# # Building a Retrieval Augmented Generation (RAG) Chatbot

# %%
# !pip install --quiet --upgrade langchain-text-splitters langchain-community langgraph
# !pip install -qU langchain-mistralai
# !pip install -qU langchain-chroma
# !pip install xmltodict

# To correct UnstructuredXMLLoader errors
# !pip install "unstructured>=0.6.7"

# %% [markdown]
# ## Setup

# %%
import getpass
import os

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter API key for Langsmith: ")
# Out:
# Enter API key for Langsmith:  ········

# %% [markdown]
# ## Components

# %%
import getpass
import os

# Chat model

if not os.environ.get("MISTRAL_API_KEY"):
  os.environ["MISTRAL_API_KEY"] = getpass.getpass("Enter API key for Mistral AI: ")

# %%
from langchain_mistralai import ChatMistralAI, MistralAIEmbeddings

# Chat model
llm = ChatMistralAI(model="mistral-large-latest")

# Embeddings model
embeddings = MistralAIEmbeddings(model="mistral-embed")

# %%
from langchain_chroma import Chroma

# Vector store
vector_store = Chroma(embedding_function=embeddings)

# %% [markdown]
# ## Loading JSON and XML files
#
# Transforming the data JSON and XML files we got online into LangChain Document objects

# %% [markdown]
# ### Test: loading a single JSON file

# %%
import json
from pathlib import Path
from pprint import pprint

file_path="../parcoursup/parcoursup_data.json"
data = json.loads(Path(file_path).read_text())
pprint(data)
# Out:
# [{'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Pluri Langues',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Pluri Sciences fondamentales et applications',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Sciences de la vie, biologie, santÃ©',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': "Ecoles d'ingÃ©nieurs",
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'DCG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Art',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 34.0,
#   'voeux': 76},
#  {'acceptations': 50,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 214.0,
#   'voeux': 348},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 12,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 68.0,
#   'voeux': 128},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Pluri Sciences',
#   'propositions_d_admissions': 5.0,
#   'voeux': 10},
#  {'acceptations': 56,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Sciences de l information et de la communication',
#   'propositions_d_admissions': 151.0,
#   'voeux': 296},
#  {'acceptations': 42,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 82.0,
#   'voeux': 155},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Licence Sciences Ã©conomiques',
#   'propositions_d_admissions': 2.0,
#   'voeux': 10},
#  {'acceptations': 76,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 151.0,
#   'voeux': 228},
#  {'acceptations': 8,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 8.0,
#   'voeux': 49},
#  {'acceptations': 17,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'D.E sanitaire',
#   'propositions_d_admissions': 20.0,
#   'voeux': 68},
#  {'acceptations': 14,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'DEUST',
#   'propositions_d_admissions': 25.0,
#   'voeux': 61},
#  {'acceptations': 10,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 10.0,
#   'voeux': 207},
#  {'acceptations': 2249,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Histoire-GÃ©ographie, GÃ©opolitique et Sciences politiques',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 2693.0,
#   'voeux': 3022},
#  {'acceptations': 171,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 550.0,
#   'voeux': 679},
#  {'acceptations': 32,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 138.0,
#   'voeux': 220},
#  {'acceptations': 234,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 838.0,
#   'voeux': 1097},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 89,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 398.0,
#   'voeux': 544},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Pluri Sciences',
#   'propositions_d_admissions': 5.0,
#   'voeux': 14},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 2.0,
#   'voeux': 9},
#  {'acceptations': 40,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 238.0,
#   'voeux': 342},
#  {'acceptations': 8,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 49.0,
#   'voeux': 1412},
#  {'acceptations': 47,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 76.0,
#   'voeux': 348},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 3.0,
#   'voeux': 10},
#  {'acceptations': 141,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 270.0,
#   'voeux': 424},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 5.0,
#   'voeux': 23},
#  {'acceptations': 19,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 105.0,
#   'voeux': 183},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Pluri Langues',
#   'propositions_d_admissions': 10.0,
#   'voeux': 46},
#  {'acceptations': 180,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 388.0,
#   'voeux': 845},
#  {'acceptations': 41,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 105.0,
#   'voeux': 213},
#  {'acceptations': 37,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 160.0,
#   'voeux': 247},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 8.0,
#   'voeux': 51},
#  {'acceptations': 15,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 50.0,
#   'voeux': 1917},
#  {'acceptations': 24,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'BUT Production',
#   'propositions_d_admissions': 54.0,
#   'voeux': 241},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'CPGE S',
#   'propositions_d_admissions': 19.0,
#   'voeux': 150},
#  {'acceptations': 23,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 36.0,
#   'voeux': 97},
#  {'acceptations': 15,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 18.0,
#   'voeux': 58},
#  {'acceptations': 342,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 577.0,
#   'voeux': 2108},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'DCG',
#   'propositions_d_admissions': 2.0,
#   'voeux': 8},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Langues, littÃ©ratures et cultures Ã©trangÃ¨res et '
#                'rÃ©gionales',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 8.0,
#   'voeux': 14},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence GÃ©nie civil',
#   'propositions_d_admissions': 9.0,
#   'voeux': 18},
#  {'acceptations': 16,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 46.0,
#   'voeux': 62},
#  {'acceptations': 12,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 45.0,
#   'voeux': 77},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence MÃ©canique, GÃ©nie mÃ©canique, IngÃ©nierie mÃ©canique',
#   'propositions_d_admissions': 1.0,
#   'voeux': 4},
#  {'acceptations': 29,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 88.0,
#   'voeux': 157},
#  {'acceptations': 19,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 39.0,
#   'voeux': 61},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 17.0,
#   'voeux': 29},
#  {'acceptations': 18,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 43.0,
#   'voeux': 160},
#  {'acceptations': 16,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 45.0,
#   'voeux': 62},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 5.0,
#   'voeux': 6},
#  {'acceptations': 9,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 42.0,
#   'voeux': 75},
#  {'acceptations': 11,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Langues et littÃ©ratures Ã©trangÃ¨res',
#   'propositions_d_admissions': 38.0,
#   'voeux': 43},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 8.0,
#   'voeux': 28},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Pluri Lettres - Langues - Sciences humaines',
#   'propositions_d_admissions': 3.0,
#   'voeux': 5},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 1.0,
#   'voeux': 2},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Pluri Sciences de la vie, de la santÃ©, de la terre et '
#                'de l univers',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Sciences de l univers, de la terre, de l espace',
#   'propositions_d_admissions': 0.0,
#   'voeux': 9},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 5.0,
#   'voeux': 9},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 18.0,
#   'voeux': 52},
#  {'acceptations': 17,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 48.0,
#   'voeux': 140},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 242,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,NumÃ©rique et Sciences Informatiques',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 315.0,
#   'voeux': 420},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 10.0,
#   'voeux': 26},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Electronique, GÃ©nie Ã©lectrique, EEA',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Formation gÃ©nÃ©rale aux mÃ©tiers de l ingÃ©nieur',
#   'propositions_d_admissions': 3.0,
#   'voeux': 5},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 10.0,
#   'voeux': 18},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences de la vie, de la santÃ©, de la terre et '
#                'de l univers',
#   'propositions_d_admissions': 0.0,
#   'voeux': 5},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences Ã©conomiques - Gestion',
#   'propositions_d_admissions': 7.0,
#   'voeux': 10},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de la vie, biologie, santÃ©',
#   'propositions_d_admissions': 5.0,
#   'voeux': 16},
#  {'acceptations': 3,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences et technologies industrielles',
#   'propositions_d_admissions': 6.0,
#   'voeux': 12},
#  {'acceptations': 48,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 87.0,
#   'voeux': 218},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'DEUST',
#   'propositions_d_admissions': 2.0,
#   'voeux': 9},
#  {'acceptations': 283,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Arts',
#   'propositions_d_admissions': 645.0,
#   'voeux': 911},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 11,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 53.0,
#   'voeux': 82},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 5.0,
#   'voeux': 12},
#  {'acceptations': 10,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 31.0,
#   'voeux': 87},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de la vie, biologie, santÃ©',
#   'propositions_d_admissions': 2.0,
#   'voeux': 6},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences et technologies industrielles',
#   'propositions_d_admissions': 3.0,
#   'voeux': 13},
#  {'acceptations': 149,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences juridiques',
#   'propositions_d_admissions': 295.0,
#   'voeux': 435},
#  {'acceptations': 5,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 36.0,
#   'voeux': 927},
#  {'acceptations': 130,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 224.0,
#   'voeux': 731},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 2.0,
#   'voeux': 50},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences Economiques et Sociales SpÃ©cialitÃ©',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 1.0,
#   'voeux': 2},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence Sciences et technologies industrielles',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 1.0,
#   'voeux': 10},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 4.0,
#   'voeux': 10},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'CPGE S',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Autres formations',
#   'propositions_d_admissions': 2.0,
#   'voeux': 13},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 23,
#   'annee_du_bac': 2021,
#   'doublette': "Art,Sciences de l'ingÃ©nieur et sciences physiques",
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 33.0,
#   'voeux': 42},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Formation gÃ©nÃ©rale aux mÃ©tiers de l ingÃ©nieur',
#   'propositions_d_admissions': 2.0,
#   'voeux': 12},
#  {'acceptations': 9,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 36.0,
#   'voeux': 51},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 2.0,
#   'voeux': 2},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Langues',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 4.0,
#   'voeux': 6},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 0.0,
#   'voeux': 3},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 5.0,
#   'voeux': 7},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de l univers, de la terre, de l espace',
#   'propositions_d_admissions': 15.0,
#   'voeux': 53},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 1.0,
#   'voeux': 6},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences religieuses',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 13,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 51.0,
#   'voeux': 67},
#  {'acceptations': 5,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 10.0,
#   'voeux': 59},
#  {'acceptations': 37,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 74.0,
#   'voeux': 218},
#  {'acceptations': 31,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'D.E sanitaire',
#   'propositions_d_admissions': 51.0,
#   'voeux': 137},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence GÃ©nie civil',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences de l information et de la communication',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences et technologies industrielles',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences juridiques',
#   'propositions_d_admissions': 2.0,
#   'voeux': 4},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences Ã©conomiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence L.AS',
#   'propositions_d_admissions': 2.0,
#   'voeux': 9},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences juridiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'BTS Agricole',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'DCG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Electronique, GÃ©nie Ã©lectrique, EEA',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Pluri Lettres - Langues - Sciences humaines',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences de l univers, de la terre, de l espace',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences de la vie, biologie, santÃ©',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'PASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'D.E sanitaire',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'DEUST',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Langues et littÃ©ratures Ã©trangÃ¨res',
#   'propositions_d_admissions': 13.0,
#   'voeux': 18},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 2.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Lettres - Sciences du langage - Arts',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences religieuses',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 31,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'BUT Production',
#   'propositions_d_admissions': 72.0,
#   'voeux': 151},
#  {'acceptations': 17,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 50.0,
#   'voeux': 107},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 2.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'CUPGE',
#   'propositions_d_admissions': 0.0,
#   'voeux': 4},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 45},
#  {'acceptations': 334,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 368.0,
#   'voeux': 392},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Electronique, GÃ©nie Ã©lectrique, EEA',
#   'propositions_d_admissions': 2.0,
#   'voeux': 2},
#  {'acceptations': 15,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 47.0,
#   'voeux': 58},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Informatique',
#   'propositions_d_admissions': 4.0,
#   'voeux': 70},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 35.0,
#   'voeux': 42},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 15.0,
#   'voeux': 86},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 9.0,
#   'voeux': 14},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Sciences humaines et sociales',
#   'propositions_d_admissions': 4.0,
#   'voeux': 4},
#  {'acceptations': 48,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence STAPS',
#   'propositions_d_admissions': 117.0,
#   'voeux': 228},
#  {'acceptations': 11,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de l univers, de la terre, de l espace',
#   'propositions_d_admissions': 65.0,
#   'voeux': 212},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences religieuses',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 101,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'PASS',
#   'propositions_d_admissions': 145.0,
#   'voeux': 293},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 1.0,
#   'voeux': 10},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 5.0,
#   'voeux': 26},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'DCG',
#   'propositions_d_admissions': 2.0,
#   'voeux': 13},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 7.0,
#   'voeux': 151},
#  {'acceptations': 1068,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Physique-Chimie SpÃ©cialitÃ©',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 1151.0,
#   'voeux': 1209},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'BTS Agricole',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'BTS Production',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 3.0,
#   'voeux': 6},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'CPGE L',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'CUPGE',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 10,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Sciences Economiques et Sociales '
#                'SpÃ©cialitÃ©',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 13.0,
#   'voeux': 15},
#  {'acceptations': 368,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Arts',
#   'propositions_d_admissions': 898.0,
#   'voeux': 1388},
#  {'acceptations': 1282,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Histoire',
#   'propositions_d_admissions': 3771.0,
#   'voeux': 4533},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 2.0,
#   'voeux': 7},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 4},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Histoire-GÃ©ographie, GÃ©opolitique et Sciences '
#                'politiques,HumanitÃ©s, LittÃ©rature et Philosophie',
# ...
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 3,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 11.0,
#   'voeux': 18},
#  {'acceptations': 120,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Arts',
#   'propositions_d_admissions': 291.0,
#   'voeux': 367},
#  {'acceptations': 3,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence GÃ©ographie',
#   'propositions_d_admissions': 18.0,
#   'voeux': 21},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 11},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 1.0,
#   'voeux': 8},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 44,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 98.0,
#   'voeux': 192},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 23.0,
#   'voeux': 34},
#  {'acceptations': 19,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'BTS Agricole',
#   'propositions_d_admissions': 24.0,
#   'voeux': 42},
#  {'acceptations': 3,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 4.0,
#   'voeux': 10},
#  {'acceptations': 4,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 4.0,
#   'voeux': 23},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'CUPGE',
#   'propositions_d_admissions': 0.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Formations des Ã©coles nationales vÃ©tÃ©rinaires',
#   'propositions_d_admissions': 0.0,
#   'voeux': 11},
#  {'acceptations': 636,
#   'annee_du_bac': 2021,
#   'doublette': 'Art,Sciences de la vie et de la Terre SpÃ©cialitÃ©',
#   'formation': 'Ensemble des bacheliers',
#   'propositions_d_admissions': 773.0,
#   'voeux': 878},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Arts',
#   'propositions_d_admissions': 1.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Langues et littÃ©ratures franÃ§aises',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Pluri Droit - Sciences Ã©co - AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Pluri Lettres - Langues - Sciences humaines',
#   'propositions_d_admissions': 2.0,
#   'voeux': 3},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Pluri Sciences Ã©conomiques - Gestion',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'CPGE ECG',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Ecoles de Commerce',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Histoire-GÃ©ographie, GÃ©opolitique et '
#                'Sciences politiques',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence GÃ©nie civil',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences de gestion',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sciences Ã©conomiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'CUPGE',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'DEUST',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,HumanitÃ©s, LittÃ©rature et Philosophie',
#   'formation': 'Sciences po',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence LEA',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence MASS',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence MathÃ©matiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence MÃ©canique, GÃ©nie mÃ©canique, IngÃ©nierie mÃ©canique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Philosophie, EpistÃ©mologie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Pluri Sciences de la vie, de la santÃ©, de la terre et '
#                'de l univers',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Pluri Sciences fondamentales et applications',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences de l information et de la communication',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'Licence Sciences politiques',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'BUT Production',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'BTS Agricole',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': 'BTS Service',
#   'propositions_d_admissions': 1.0,
#   'voeux': 1},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': "Ecoles d'ingÃ©nieurs",
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,Langues, littÃ©ratures et cultures '
#                'Ã©trangÃ¨res et rÃ©gionales',
#   'formation': "Formations d'ART",
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence AES',
#   'propositions_d_admissions': 7.0,
#   'voeux': 9},
#  {'acceptations': 2,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Chimie',
#   'propositions_d_admissions': 15.0,
#   'voeux': 42},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence MathÃ©matiques et informatique',
#   'propositions_d_admissions': 0.0,
#   'voeux': 0},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Physique',
#   'propositions_d_admissions': 1.0,
#   'voeux': 19},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Physique et chimie',
#   'propositions_d_admissions': 0.0,
#   'voeux': 19},
#  {'acceptations': 11,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Psychlogie, Sciences cognitives',
#   'propositions_d_admissions': 25.0,
#   'voeux': 44},
#  {'acceptations': 5,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences de l Ã©ducation',
#   'propositions_d_admissions': 12.0,
#   'voeux': 24},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences du langage - Linguistique',
#   'propositions_d_admissions': 4.0,
#   'voeux': 8},
#  {'acceptations': 7,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences juridiques',
#   'propositions_d_admissions': 18.0,
#   'voeux': 31},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sciences Ã©conomiques',
#   'propositions_d_admissions': 4.0,
#   'voeux': 7},
#  {'acceptations': 1,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Licence Sociologie, DÃ©mographie',
#   'propositions_d_admissions': 15.0,
#   'voeux': 18},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'PASS',
#   'propositions_d_admissions': 22.0,
#   'voeux': 60},
#  {'acceptations': 8,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'BUT Service',
#   'propositions_d_admissions': 16.0,
#   'voeux': 59},
#  {'acceptations': 0,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'D.E  social',
#   'propositions_d_admissions': 0.0,
#   'voeux': 2},
#  {'acceptations': 6,
#   'annee_du_bac': 2021,
#   'doublette': 'Biologie/Ecologie,MathÃ©matiques SpÃ©cialitÃ©',
#   'formation': 'Autres formations',
#   'propositions_d_admissions': 15.0,
#   'voeux': 53},
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
from langchain_community.document_loaders import JSONLoader

loader = JSONLoader(
    file_path="../parcoursup/parcoursup_data.json",
    jq_schema=".[]",
    text_content=False
)

documents = loader.load()
pprint(documents[0])
# Out:
# Document(metadata={'source': 'C:\\Users\\Laura GALINDO\\Documents\\Academique_et_pro\\Epitech Digital School\\Bootcamp Chatbot IA\\chatbot-orientation-pro\\parcoursup\\parcoursup_data.json', 'seq_num': 1}, page_content='{"annee_du_bac": 2021, "doublette": "Art,Art", "formation": "Licence Chimie", "voeux": 0, "propositions_d_admissions": 0, "acceptations": 0}')

# %% [markdown]
# ### Test: loading a single XML file

# %%
from bs4 import BeautifulSoup

with open('../onisep/Onisep_Fiches_Formations.xml', 'r', encoding="utf-8") as f:
    data = f.read()

bs_data = BeautifulSoup(data, 'xml')

print(bs_data.prettify()[:500])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <formations xmlns:exsl="http://exslt.org/common">
#  <formation>
#   <identifiant>
#    FOR.1000
#   </identifiant>
#   <code_scolarite>
#    16X20003
#   </code_scolarite>
#   <libelle_complet>
#    mastère spé. management de la qualité, de la sécurité et de l'environnement
#   </libelle_complet>
#   <sigle/>
#   <libelle_generique/>
#   <libelle_specifique/>
#   <type_option/>
#   <type_Formation>
#    <type_formation_sigle>
#     mastère spé.
#    </type_formation_sigle>
#    <type_formation

# %%
from langchain_community.document_loaders import UnstructuredXMLLoader
from pprint import pprint

loader = UnstructuredXMLLoader('../onisep/Onisep_Fiches_Formations.xml')

documents = loader.load()

print(documents[0].page_content[:500])
# Out:
# FOR.1000
#
# 16X20003
#
# mastère spé. management de la qualité, de la sécurité et de l'environnement
#
# mastère spé.
#
# MASTERE SPE
#
# mastère spécialisé
#
# "1 an"
#
# https://www.francecompetences.fr/recherche/rncp/37084/
#
# 200
#
# Spécialités pluritechnologiques de la production
#
# R
#
# Contrôle, prévention, entretien
#
# niveau 7
#
# REF.423
#
# bac + 6
#
# 16X
#
# Label de la Conférence des grandes écoles (CGE)
#
# Formation inscrite au RNCP
#
# MET.878
#
# chargé/e hygiène sécurité environnement (HSE)
#
# chargée hygiène sécurité environnem

# %% [markdown]
# ### Converting XML files to JSON files
#
# The layout of Document objects loaded from XML files is too different from JSON files, and less well structured, so the MistralAI API cannot later embed them into the vector store

# %%
import json
import xmltodict

def convert_xml_to_json(xml_file: str, json_file: str):
    try:
        with open(xml_file, 'r', encoding='utf-8') as f:
            xml_content = f.read()

        data_dict = xmltodict.parse(xml_content)

        formations = data_dict.get("formations", {})
        if isinstance(formations, dict):
            formations = formations.get("formation", [])
        else:
            formations = []

        processed_formations = []

        for formation in formations:
            processed_entry = {}

            # Direct string fields
            processed_entry["identifiant"] = formation["identifiant"] if "identifiant" in formation else None
            processed_entry["libelle_complet"] = formation["libelle_complet"] if "libelle_complet" in formation else None
            processed_entry["duree_formation"] = formation["duree_formation"].strip('"') if "duree_formation" in formation else None
            processed_entry["url"] = formation["url"] if "url" in formation else None
            processed_entry["niveau_certification"] = formation["niveau_certification"] if "niveau_certification" in formation else None
            processed_entry["poursuites_etudes"] = formation["poursuites_etudes"] if "poursuites_etudes" in formation else None
            processed_entry["publications"] = formation["publications"] if "publications" in formation else None

            # Nested structures
            if "type_Formation" in formation and isinstance(formation["type_Formation"], dict):
                processed_entry["type_Formation"] = formation["type_Formation"].get("type_formation_libelle", None)
            else:
                processed_entry["type_Formation"] = None

            if "niveau_etudes" in formation and isinstance(formation["niveau_etudes"], dict):
                processed_entry["niveau_etudes"] = formation["niveau_etudes"].get("libelle", None)
            else:
                processed_entry["niveau_etudes"] = None

            if "nsf_discipline" in formation and isinstance(formation["nsf_discipline"], dict):
                processed_entry["nsf_discipline"] = formation["nsf_discipline"].get("NSF_discipline_libelle", None)
            else:
                processed_entry["nsf_discipline"] = None

            if "nature_certificat" in formation and isinstance(formation["nature_certificat"], dict):
                certif = formation["nature_certificat"].get("libelle_nature_certificat", None)
                processed_entry["nature_certificat"] = ", ".join(certif) if isinstance(certif, list) else certif
            else:
                processed_entry["nature_certificat"] = None

            # Handling "metiers_formation" properly
            processed_entry["metiers_formation"] = []
            if "metiers_formation" in formation and isinstance(formation["metiers_formation"], dict):
                metiers = formation["metiers_formation"].get("metier", [])

                if isinstance(metiers, dict):  # If there is only one "metier"
                    metiers = [metiers]

                for metier in metiers:
                    metier_data = {"nom_metier": metier.get("nom_metier", None), "synonymes": []}

                    if "synonymes" in metier and isinstance(metier["synonymes"], dict):
                        synonyms = metier["synonymes"].get("synonyme", [])

                        if isinstance(synonyms, dict):  # If there is only one synonym
                            synonyms = [synonyms]

                        metier_data["synonymes"] = [syn.get("nom_metier") for syn in synonyms if isinstance(syn, dict)]

                    processed_entry["metiers_formation"].append(metier_data)

            processed_formations.append(processed_entry)

        with open(json_file, 'w', encoding='utf-8') as f:
            json.dump(processed_formations, f, ensure_ascii=False, indent=4)

        print(f"Conversion réussie : '{xml_file}' → '{json_file}'")

    except Exception as e:
        print(f"Erreur lors de la conversion : {e}")

# Exemple d'utilisation
convert_xml_to_json("../onisep/Onisep_Fiches_Formations.xml", "../onisep/Onisep_Fiches_Formations.json")
# Out:
# Conversion réussie : '../onisep/Onisep_Fiches_Formations.xml' → '../onisep/Onisep_Fiches_Formations.json'

# %%
xml_file = '../onisep/Onisep_Fiches_Metiers.xml'
json_file = '../onisep/Onisep_Fiches_Metiers.json'
convert_xml_to_json(xml_file, json_file)
# Out:
# Converted '../onisep/Onisep_Fiches_Formations.xml' to '../onisep/Onisep_Fiches_Formations.json' successfully
# Converted '../onisep/Onisep_Fiches_Metiers.xml' to '../onisep/Onisep_Fiches_Metiers.json' successfully

# %% [markdown]
# ### Loading multiple JSON files as LangChain Document objects

# %%
import os
import json
from pathlib import Path
from langchain.docstore.document import Document
from langchain_community.document_loaders import JSONLoader, UnstructuredXMLLoader

# To correct UnstructuredXMLLoader errors
# import nltk
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

def load_json_documents(file_path: str) -> list:
    """
    Load a JSON file using JSONLoader and return a list of Documents
    """
    loader = JSONLoader(
        file_path=file_path,
        jq_schema=".[]",
        text_content=False,
    )
    try:
        documents = loader.load()
        print(f"[JSON] Loaded file: {file_path} ({len(documents)} document(s))")
        return documents
    except Exception as e:
        print(f"Error while loading JSON file {file_path} : {e}")
        return []

# def load_xml_documents(file_path: str) -> list:
#    """
#    Load an XML file using UnstructuredXMLLoader and return a list of Documents
#    """
#    loader = UnstructuredXMLLoader(file_path)
#    try:
#        documents = loader.load()
#        print(f"[XML] Loaded file: {file_path} ({len(documents)} document(s))")
#        return documents
#    except Exception as e:
#        print(f"Error while loading XML file {file_path} : {e}")
#        return []

def load_documents(file_paths: list) -> list:
    """
    For each file in the list, we determine its extension and call the appropriate loader
    (JSONLoader or UnstructuredXMLLoader), and then return a complete list of Documents
    """
    documents = []
    for fp in file_paths:
        ext = Path(fp).suffix.lower()
        if ext == ".json":
            documents.extend(load_json_documents(fp))
#        elif ext == ".xml":
#            documents.extend(load_xml_documents(fp))
        else:
            print(f"Unsupported file (extension {ext}) : {fp}")
    return documents

def export_documents(documents: list):
    """
    Save the Document objects to a text file for inspection or debugging
    """
    with open("loaded_documents.txt", "w", encoding="utf-8") as f:
        for doc in documents:
            f.write(f"Source: {doc.metadata.get('source')}\n")
            f.write(f"Content:\n{doc.page_content}\n\n---\n\n")
    
    print("Documents saved to 'loaded_documents.txt'")

# %%
# List of JSON and XML files to load
file_list = [
    # DONE:
    # "../parcoursup/parcoursup_data.json",
    # "../mon_master/monmaster_data.json",
    # "../salons/salons_january.json",
    # "../salons/salons_february.json",
    # "../salons/salons_march.json",
    # "../salons/salons_may_june.json"
    # "../France_travail/Competences-themes.json",
    # "../France_travail/Francetravail Scraper debutant.json",
    # "../France_travail/Francetravail Scraper junior .json",
    # "../France_travail/Francetravail_Scraper_Global.json",
    # "../France_travail/Nombre_offres_themes.json",
    # "../mbti/mbti_jobs.json",
    # "../onisep/Onisep_Fiches_Formations.json",
    # TODO:
    #"../onisep/Onisep_Fiches_Metiers.json",
    
]

# Load all the documents
all_documents = load_documents(file_list)

print(f"\nTotal number of loaded documents: {len(all_documents)}")

export_documents(all_documents)
# Out:
# [JSON] Loaded file: ../onisep/Onisep_Fiches_Formations.json (2249 document(s))
#
# Total number of loaded documents: 2249
# Documents saved to 'loaded_documents.txt'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

def dynamic_split_documents(documents, base_chunk_size=1000, min_chunks=3, max_chunks=200):
    """
    Dynamically split a list of documents into smaller chunks based on document size
    
    Parameters:
        - documents: List of LangChain Document objects
        - base_chunk_size: Default chunk size in characters
        - min_chunks: Minimum number of chunks per document
        - max_chunks: Maximum number of chunks per document
    
    Returns:
        - List of split documents
    """
    all_splits = []
    
    for doc in documents:
        doc_length = len(doc.page_content)
        
        # Dynamically adjust the chunk size:
        # - Ensure chunks are not too small by using at least `base_chunk_size`
        # - Ensure chunks are not too big by keeping at least `min_chunks` per document
        # - This balances the number and size of chunks for better retrieval
        chunk_size = max(base_chunk_size, doc_length // max_chunks)  # Prevents chunks from being too tiny
        chunk_size = min(chunk_size, doc_length // min_chunks)  # Ensures we don't have too few large chunks
        
        # Define the text splitter
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size,
            chunk_overlap=chunk_size // 5,  # 20% overlap
            add_start_index=True # Keeps track of where in the original document each chunk came from
        )
        
        # Split the document and extend the list
        splits = text_splitter.split_documents([doc])
        # print(f"Document: {doc.metadata.get('source')} | Original Length: {len(doc.page_content)} | Chunks Created: {len(splits)}")
        
        all_splits.extend(splits) # Adds all the elements in splits to all_splits, one by one
    
    print(f"\nTotal number of chunks created: {len(all_splits)}")
    return all_splits

def export_split_documents(chunks):
    """
    Save the split documents to a text file with delimiters between chunks

    Each document chunk's source and content are written to 'split_documents.txt', 
    with '---' as a separator between different chunks.

    Parameters:
        - chunks (list): A list of LangChain Document objects after splitting

    Returns:
        - File containing all split document chunks with delimiters
    """
    with open("split_documents.txt", "w", encoding="utf-8") as f:
        for i, chunk in enumerate(chunks):
            # Add delimiter before every chunk except the first one
            if i > 0:
                f.write("\n---\n\n")

            f.write(f"Source: {chunk.metadata.get('source')}\n")
            f.write(f"Content:\n{chunk.page_content}\n")

    print("Split documents saved to 'split_documents.txt'")


# Split the loaded documents
split_documents = dynamic_split_documents(all_documents)

export_split_documents(split_documents)
# Out:
# Total number of chunks created: 9083
# Split documents saved to 'split_documents.txt'

# %% [markdown]
# ## Storing Document splits
#
# Indexing our chunks of documents to be able to vector search over them at runtime, which entails embedding the contents of each chunk of Document into the Chroma vector store

# %%
import time

def batch_embed_documents(split_documents, vector_store, batch_size=10, sleep_time=2):
    """
    Embed Documents in batches and add them to the vector store

    Parameters:
        - split_documents (list): List of document chunks to embed
        - vector_store: The vector database where embeddings are stored
        - batch_size (int): Number of documents per batch (default is 10)
        - sleep_time (int): Time to wait (in seconds) between batches to avoid API rate limits (default is 2)
    
    Returns:
        - None
    """
    for i in range(0, len(split_documents), batch_size):
        batch = [chunk for chunk in split_documents[i:i + batch_size]]

        try:
            document_ids = vector_store.add_documents(documents=batch)
            print(f"Batch {i // batch_size + 1}: {document_ids[:3]}")
        except Exception as e:
            print(f"Error in batch {i // batch_size + 1}: {e}")

        time.sleep(sleep_time)  # Pause to prevent API rate limiting


batch_embed_documents(split_documents, vector_store)
# Out:
# Batch 1: ['de9e4f4c-29c2-4705-9c2d-7be0be97a67d', '17040faf-2819-4279-92fc-e55e20ce1347', '794f0570-ff3a-4ef6-81e5-3d580fc5dfce']
# Batch 2: ['2eb2776f-13cc-43ab-bbd4-10235015d643', '5a82a80b-b83b-4584-a0ec-52df3530708c', 'ef36adac-682e-459f-9629-b6dfee4d1360']
# Batch 3: ['43c81f99-a10c-4ec9-9e33-fda0558edc18', '983b4a73-e410-44c8-af56-22792683ffa3', 'fade1e42-6ac9-421a-b432-965bd2be94c2']
# Batch 4: ['7b868811-251d-47b0-bca0-329b0103b5f4', 'd8722a2d-5ffd-4a33-ace6-cd9a9ef0f62b', '1b8c983b-6dce-4069-9abd-c5abcdd6af5e']
# Batch 5: ['13ca2d6c-6b8e-443d-a484-c98dd8a1476a', '5a7b20fa-00a8-4f6a-8875-b3daf6a92822', 'ac89cdcc-79b2-4b07-b6cd-6153933dbf26']
# Batch 6: ['f3c90249-f5d1-45d4-a152-25760c9c92fd', 'c1baa4ad-6cee-4457-975f-722a38247823', '2e26a1c7-0ea4-4c61-8e9c-e126de70035f']
# Batch 7: ['f9035b71-44c0-4239-ab08-1eb692c9308d', '6677552f-4596-4425-b517-689061f552d5', '7e9dc40a-e20d-46a1-9c35-ddcd5b5db0f2']
# Batch 8: ['1972770e-79b7-403e-be06-c2a4cc62cbb0', '65ea8df2-e113-4e3e-b72c-b09e9e5eae34', '956bf8bb-b809-4258-9831-315e6ed444ac']
# Batch 9: ['1dd35bf2-a589-4cb8-99db-607d13d9cc17', '7c529a99-97e0-4527-a74b-3c6669108f57', '491452a1-07d8-4537-bdb8-a202135cb9c1']
# Batch 10: ['ca4bd19d-ebff-405d-bbb0-4e8e52a975fa', 'a6c7fc22-3cbf-45ac-80be-7d660db7d2a3', 'ca5fa8b5-6bf4-4475-b01b-22f749407545']
# Batch 904: ['2c26b963-91e0-409f-9952-ffb4d4879db9', '77eba021-7718-4d92-8214-d0493ff5f849', '17aeee9a-4383-49ab-b862-697e4fd428e6']
# Batch 905: ['d963b7b2-62ca-44f9-b51b-226f99c6aa1e', '130f7d06-62d2-4608-a703-50e85e16c338', '94813046-1c09-4fa5-9bef-c60eaa06ae92']
# Batch 906: ['76994a60-a4d1-400c-bff3-894410ed2e06', '6e4bb1ed-8bf4-4511-8439-172fa5cbb8db', '88de5fa3-9237-415b-9dad-ac776ee4ffc1']
# Batch 907: ['d413123d-50c3-4a78-8021-5003ea9a90af', '6e6ab69b-313e-4e6d-8853-070239427ff7', '05bb1c84-2192-4624-b960-7737e5a2988b']
# Batch 908: ['54bbbe67-3dca-46a8-862e-89bf721d1ef2', 'ee7fb4bf-8f8f-45fe-b32c-92d9edda3bff', '7a0d2819-22e1-4191-acfd-d2686c1af6f2']
# Batch 909: ['25645219-71ce-4471-b804-1ce0d59876ae', 'ca9cc6a8-6615-491d-acdc-04f4f45d4d2f', '76d18e47-a6fb-45cf-8b0d-18212de841cd']

# %%
failed_batches = list(range(407, 653))
failed_batches.append(690)
failed_batches.append(757)

import time

def rerun_failed_batches(split_documents, vector_store, failed_batches, batch_size=10, sleep_time=2):
    """
    Re-run failed batches of document embeddings.

    Parameters:
        - split_documents (list): List of document chunks to embed
        - vector_store: The vector database where embeddings are stored
        - failed_batches (list): List of failed batch indices (starting from 1)
        - batch_size (int): Number of documents per batch (default is 10)
        - sleep_time (int): Time to wait (in seconds) between batches to avoid API rate limits (default is 2)
    
    Returns:
        - None
    """
    for batch_num in failed_batches:
        start_idx = (batch_num - 1) * batch_size
        batch = split_documents[start_idx:start_idx + batch_size]

        if not batch:  # Skip if the batch is empty
            print(f"Skipping empty batch {batch_num}")
            continue

        try:
            document_ids = vector_store.add_documents(documents=batch)
            print(f"Re-ran batch {batch_num}: {document_ids[:3]}")
        except Exception as e:
            print(f"Error re-running batch {batch_num}: {e}")

        time.sleep(sleep_time)  # Pause to prevent API rate limiting

# Example usage:
rerun_failed_batches(split_documents, vector_store, failed_batches)

# %% [markdown]
# ## Creating the RAG chain with LangChain
#
# Creating a retrieval chain that, based on a user question, will retrieve relevant Documents from Chroma and provide them in context to the MistralAI language model to generate an informed answer

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain import hub

# Interface that interrogates the vector store
retriever = vecteur_store.as_retriever(search_kwargs={"k": 5})  # the k most relevant chunks of documents

# Load a pre-defined prompt template for retrieval-based Q&A.
# This template helps structure the input for the AI model.
retrieval_chat_prompt = hub.pull("langchain-ai/retrieval-qa-chat")

# Create a document combination chain.
# This step tells the AI how to process and merge the retrieved documents
# before generating an answer.
combine_docs_chain = create_stuff_documents_chain(llm, retrieval_chat_prompt)

# Create the retrieval chain.
# This connects the retriever with the AI model.
retrieval_chain = create_retrieval_chain(retriever, combine_docs_chain)

# %%
# Example usage
response = retrieval_chain.invoke({"input": "..."})
print(response)

# %%
question = "Quelles formations sont recommandées pour un profil INFP qui souhaite travailler dans l’éducation ?"
reponse = retrieval_chain.run(question)
print(reponse)
